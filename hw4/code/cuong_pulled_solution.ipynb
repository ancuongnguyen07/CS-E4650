# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
class Dolphin:
    def __init__(self, name: str, gender: str):
        self.name = name
        self.gender = gender

    def __str__(self):
        return f'Name: {self.name:<15} | Gender: {self.gender}'

# %%
# Build a dolphin dictionary
dolphins: list[Dolphin] = []
with open('data/dolphininfo.txt', 'r') as f:
    for idx, line in enumerate(f):
        name, gender = line.strip().split()
        new_dolphin = Dolphin(name,gender)
        dolphins.append(new_dolphin)

for i in range(5):
    print(dolphins[i])
# Out:
# Name: Beak            | Gender: M
# Name: Beescratch      | Gender: M
# Name: Bumper          | Gender: M
# Name: CCL             | Gender: F
# Name: Cross           | Gender: M

# %%
# Build a dolphines network
dolphin_graph = nx.Graph()

with open('data/dolphins.txt', 'r') as f:
    lines = f.readlines()
    
    no_nodes = int(lines[0])
    dolphin_graph.add_nodes_from([dolphins[i].name for i in range(no_nodes)])

    # dolphin_graph.add_edges_from([tuple(map(int, line.split())) for line in lines[1:]])
    for line in lines[1:]:
        startpoint, endpoint = map(lambda x: int(x)-1, line.split())
        dolphin_graph.add_edge(dolphins[startpoint].name, dolphins[endpoint].name)

# Draw the network
nx.draw(dolphin_graph, with_labels=True)

# %%
print(f'Grin degree: {dolphin_graph.degree("Grin")}')
print(f'Grin neighbors: {list(dolphin_graph.neighbors("Grin"))}')

dolphin_dict = {dolphin.name: dolphin.gender for dolphin in dolphins}
# Out:
# Grin degree: 12
# Grin neighbors: ['Beak', 'CCL', 'Hook', 'MN83', 'Scabs', 'Shmuddel', 'SN4', 'SN63', 'SN9', 'Stripes', 'TR99', 'TSN103']

# %%
# Question a

# tested candidate set counter for both algorithms
tcs_basic_counter = 0
tcs_improved_counter = 0

class CliqueSet:
    def __init__(self, nodes: set[str], G: nx.Graph):
        self.nodes = nodes
        # Sort nodes to make the key distinct without considering the order
        # and make the output string more readable
        self.__sorted_nodes = sorted(nodes)
        self.fs = self.__calculate_fs(self.nodes, G)
    

    def should_add_node(self, v: str, G: nx.Graph, alpha: float) -> bool:
        '''
        Check if the current clique set could be extended by adding node v.
        '''
        new_nodes = self.nodes.union({v})
        fs = self.__calculate_fs(new_nodes, G)
        return not any(fs < self.__upper_bound(new_nodes, G, u, alpha) for u in new_nodes)


    def union(self, other: set[str], G: nx.graph) -> 'CliqueSet':
        '''
        Return a new CliqueSet by unioning the current set with another set.
        '''
        return CliqueSet(self.nodes.union(other), G)
    

    def __calculate_fs(self, nodes: set[str], G: nx.Graph) -> float:
        '''
        Return f(S) = min_{v in S} degree(v, S) / (|S| - 1)
        '''
        if len(nodes) == 1:
            return 1
        degrees_S_v = [len([u for u in G.neighbors(v) if u in nodes]) for v in nodes]
        return min(degrees_S_v) / (len(nodes) - 1)
    

    def __upper_bound(self, nodes: set[str], G: nx.Graph, v: str, alpha: float) -> float:
        return 1 - (G.degree[v] * (1-alpha)) / ((len(nodes) - 1) * alpha)
    

    def __key(self):
        return tuple(self.__sorted_nodes)


    def __hash__(self):
        return hash(self.__key())
    
    
    def __eq__(self, other):
        if isinstance(other, CliqueSet):
            return self.nodes == other.nodes
        return False
    
    
    def __lt__(self, other):
        if not isinstance(other, CliqueSet):
            return NotImplemented
        
        if len(self.nodes) == len(other.nodes):
            return self.__sorted_nodes < other.__sorted_nodes
        return len(self.__sorted_nodes) < len(other.__sorted_nodes)
    

    def __len__(self):
        return len(self.nodes)
    

    def __iter__(self):
        return iter(self.nodes)
    

    def __str__(self):
        return f'{str(self.__sorted_nodes):<70} | fs: {self.fs:.2f}'



def dfs(S: CliqueSet, G: nx.Graph, start: str, visited: set[str], cliques: set[CliqueSet],
        alpha: float) -> None:
    '''
    Recursive Depth-First-Search (DFS) to find alpha-clique sets.
    '''
    global tcs_basic_counter
    tcs_basic_counter += 1

    visited.add(start)
    if S.fs >= alpha:
        cliques.add(S)

    for v in G.neighbors(start):
        if v not in visited and S.should_add_node(v, G, alpha):
            new_S = S.union({v}, G)
            # new_candidates = G.neighbors(v)
            dfs(new_S, G, v, visited, cliques, alpha)


def dfs_improved(S: CliqueSet, G: nx.Graph, start: str, visited: set[str], cliques: set[CliqueSet],
        alpha: float) -> None:
    '''
    Recursive Depth-First-Search (DFS) to find alpha-clique sets.
    The upper bound is maximized to improve pruning effect.
    '''
    global tcs_improved_counter
    tcs_improved_counter += 1

    visited.add(start)
    if S.fs >= alpha:
        cliques.add(S)

    # Sort candidates by degree (ascending) to maximize pruning effect
    # The idea is to maximize the upper bound, which means maximize
    # 1 - (G.degree[v] * (1-alpha)) / ((len(S) - 1) * alpha)
    # equivalent to minimize (G.degree[v] * (1-alpha)) / ((len(S) - 1) * alpha)
    # equivalent to minimize G.degree[v]
    # equivalent to prioritize nodes with lower degree
    candidates = list(G.neighbors(start))
    sorted_candidates = sorted(candidates, key=lambda v: G.degree[v])

    for v in sorted_candidates:
        if v not in visited and S.should_add_node(v, G, alpha):
            new_S = S.union({v}, G)
            # new_candidates = G.neighbors(v)
            dfs_improved(new_S, G, v, visited, cliques, alpha)


def find_alpha_cliques(G: nx.Graph, alpha: float, adv_alg = False) -> list[set[str]]:
    '''
    Find all alpha-cliques in graph G.
    Using the improved DFS algorithm if adv_alg is True.
    Otherwise, using the basic DFS algorithm by default.
    '''
    cliques = set()
    if adv_alg:
        for v in G.nodes:
            visited = set()
            dfs_improved(CliqueSet({v}, G), G, v, visited, cliques, alpha)
    else:
        for v in G.nodes:
            visited = set()
            dfs(CliqueSet({v}, G), G, v, visited, cliques, alpha)

    return sorted(cliques, reverse=True)

# %%
alpha = 0.8

# Run the basic algorithm
cliques = find_alpha_cliques(dolphin_graph, alpha)
print(f'Number of tested candidate sets: {tcs_basic_counter}')
print(f'Number of {alpha}-cliques: {len(cliques)}')
for clique in cliques:
    print(clique)
# Out:
# Number of tested candidate sets: 621
# Number of 0.8-cliques: 201
# ['Grin', 'Hook', 'SN4', 'SN63', 'Scabs', 'Stripes']                    | fs: 0.80
# ['DN21', 'Feather', 'Gallatin', 'Jet', 'Web']                          | fs: 1.00
# ['Jonah', 'MN105', 'Patchback', 'Trigger']                             | fs: 1.00
# ['Grin', 'SN4', 'Scabs', 'Shmuddel']                                   | fs: 1.00
# ['Grin', 'Hook', 'Scabs', 'TR99']                                      | fs: 1.00
# ['Grin', 'Hook', 'SN63', 'Scabs']                                      | fs: 1.00
# ['Grin', 'Hook', 'SN4', 'Scabs']                                       | fs: 1.00
# ['DN21', 'Feather', 'Gallatin', 'Jet']                                 | fs: 1.00
# ['DN16', 'Feather', 'Gallatin', 'Web']                                 | fs: 1.00
# ['Beak', 'Fish', 'SN96', 'TR77']                                       | fs: 1.00
# ['MN83', 'Patchback', 'Topless']                                       | fs: 1.00
# ['MN60', 'Topless', 'Trigger']                                         | fs: 1.00
# ['Kringel', 'SN63', 'Thumper']                                         | fs: 1.00
# ['Jonah', 'MN105', 'Trigger']                                          | fs: 1.00
# ['Jonah', 'MN105', 'Patchback']                                        | fs: 1.00
# ['Jet', 'Mus', 'Number1']                                              | fs: 1.00
# ['Haecksel', 'Jonah', 'MN83']                                          | fs: 1.00
# ['Grin', 'SN9', 'TSN103']                                              | fs: 1.00
# ['Grin', 'SN63', 'TSN103']                                             | fs: 1.00
# ['Grin', 'SN4', 'Scabs']                                               | fs: 1.00
# ['Grin', 'Hook', 'TR99']                                               | fs: 1.00
# ['Grin', 'Hook', 'Scabs']                                              | fs: 1.00
# ['Grin', 'Hook', 'SN63']                                               | fs: 1.00
# ['Feather', 'Gallatin', 'Ripplefluke']                                 | fs: 1.00
# ['Double', 'Topless', 'Zap']                                           | fs: 1.00
# ['Double', 'SN4', 'Topless']                                           | fs: 1.00
# ['Double', 'Kringel', 'Oscar']                                         | fs: 1.00
# ['DN63', 'Knit', 'Upbang']                                             | fs: 1.00
# ['DN63', 'Knit', 'PL']                                                 | fs: 1.00
# ['DN21', 'Feather', 'Gallatin']                                        | fs: 1.00
# ['DN16', 'Feather', 'Web']                                             | fs: 1.00
# ['DN16', 'Feather', 'Gallatin']                                        | fs: 1.00
# ['CCL', 'Double', 'Zap']                                               | fs: 1.00
# ['Bumper', 'Fish', 'SN96']                                             | fs: 1.00
# ['Beescratch', 'SN90', 'Upbang']                                       | fs: 1.00
# ['Beescratch', 'Notch', 'Number1']                                     | fs: 1.00
# ['Beescratch', 'Knit', 'Upbang']                                       | fs: 1.00
# ['Beescratch', 'Jet', 'Number1']                                       | fs: 1.00
# ['Beak', 'Haecksel', 'SN9']                                            | fs: 1.00
# ['Beak', 'Grin', 'SN9']                                                | fs: 1.00
# ['Beak', 'Fish', 'TR77']                                               | fs: 1.00
# ['Beak', 'Fish', 'SN96']                                               | fs: 1.00
# ['Upbang', 'Web']                                                      | fs: 1.00
# ['Trigger', 'Vau']                                                     | fs: 1.00
# ['TSN83', 'Zipfel']                                                    | fs: 1.00
# ['TR82', 'Web']                                                        | fs: 1.00
# ['TR120', 'TR88']                                                      | fs: 1.00
# ['Stripes', 'TSN83']                                                   | fs: 1.00
# ['Stripes', 'TR120']                                                   | fs: 1.00
# ['Shmuddel', 'Thumper']                                                | fs: 1.00
# ['Shmuddel', 'TR88']                                                   | fs: 1.00
# ['SN9', 'TSN103']                                                      | fs: 1.00
# ['SN89', 'Web']                                                        | fs: 1.00
# ['SN63', 'Whitetip']                                                   | fs: 1.00
# ['SN63', 'Thumper']                                                    | fs: 1.00
# ['SN4', 'Zipfel']                                                      | fs: 1.00
# ['SN100', 'SN9']                                                       | fs: 1.00
# ['SN100', 'SN89']                                                      | fs: 1.00
# ['SN100', 'SN4']                                                       | fs: 1.00
# ['Ripplefluke', 'Zig']                                                 | fs: 1.00
# ['Patchback', 'TSN103']                                                | fs: 1.00
# ['Patchback', 'Stripes']                                               | fs: 1.00
# ['Patchback', 'SMN5']                                                  | fs: 1.00
# ['PL', 'TR77']                                                         | fs: 1.00
# ['PL', 'SN96']                                                         | fs: 1.00
# ['Oscar', 'PL']                                                        | fs: 1.00
# ['Mus', 'Number1']                                                     | fs: 1.00
# ['Mus', 'Notch']                                                       | fs: 1.00
# ['MN83', 'Topless']                                                    | fs: 1.00
# ['MN60', 'Trigger']                                                    | fs: 1.00
# ['MN60', 'Topless']                                                    | fs: 1.00
# ['MN60', 'SN100']                                                      | fs: 1.00
# ['MN105', 'Scabs']                                                     | fs: 1.00
# ['Kringel', 'Thumper']                                                 | fs: 1.00
# ['Kringel', 'TR77']                                                    | fs: 1.00
# ['Kringel', 'SN63']                                                    | fs: 1.00
# ['Jonah', 'Trigger']                                                   | fs: 1.00
# ['Jonah', 'Patchback']                                                 | fs: 1.00
# ['Jonah', 'MN83']                                                      | fs: 1.00
# ['Jonah', 'MN105']                                                     | fs: 1.00
# ['Jonah', 'Kringel']                                                   | fs: 1.00
# ['Jet', 'Quasi']                                                       | fs: 1.00
# ['Jet', 'Mus']                                                         | fs: 1.00
# ['Jet', 'MN23']                                                        | fs: 1.00
# ['Hook', 'Kringel']                                                    | fs: 1.00
# ['Haecksel', 'Zap']                                                    | fs: 1.00
# ['Haecksel', 'Vau']                                                    | fs: 1.00
# ['Haecksel', 'Jonah']                                                  | fs: 1.00
# ['Grin', 'TSN103']                                                     | fs: 1.00
# ['Grin', 'TR99']                                                       | fs: 1.00
# ['Grin', 'Stripes']                                                    | fs: 1.00
# ['Grin', 'Shmuddel']                                                   | fs: 1.00
# ['Grin', 'Scabs']                                                      | fs: 1.00
# ['Grin', 'SN63']                                                       | fs: 1.00
# ['Grin', 'SN4']                                                        | fs: 1.00
# ['Grin', 'MN83']                                                       | fs: 1.00
# ['Grin', 'Hook']                                                       | fs: 1.00
# ['Gallatin', 'Upbang']                                                 | fs: 1.00
# ['Gallatin', 'Ripplefluke']                                            | fs: 1.00
# ['Fork', 'Scabs']                                                      | fs: 1.00
# ['Five', 'Trigger']                                                    | fs: 1.00
# ['Fish', 'Patchback']                                                  | fs: 1.00
# ['Feather', 'Ripplefluke']                                             | fs: 1.00
# ['Double', 'Topless']                                                  | fs: 1.00
# ['Double', 'SN4']                                                      | fs: 1.00
# ['Double', 'Oscar']                                                    | fs: 1.00
# ['Double', 'Kringel']                                                  | fs: 1.00
# ['DN63', 'SN9']                                                        | fs: 1.00
# ['DN63', 'PL']                                                         | fs: 1.00
# ['DN63', 'Number1']                                                    | fs: 1.00
# ['DN63', 'Knit']                                                       | fs: 1.00
# ['DN21', 'Wave']                                                       | fs: 1.00
# ['DN21', 'Feather']                                                    | fs: 1.00
# ['DN16', 'Web']                                                        | fs: 1.00
# ['DN16', 'Wave']                                                       | fs: 1.00
# ['DN16', 'Gallatin']                                                   | fs: 1.00
# ['DN16', 'Feather']                                                    | fs: 1.00
# ['Cross', 'Trigger']                                                   | fs: 1.00
# ['CCL', 'Zap']                                                         | fs: 1.00
# ['CCL', 'Grin']                                                        | fs: 1.00
# ['CCL', 'Double']                                                      | fs: 1.00
# ['Bumper', 'Zipfel']                                                   | fs: 1.00
# ['Bumper', 'Thumper']                                                  | fs: 1.00
# ['Bumper', 'SN96']                                                     | fs: 1.00
# ['Bumper', 'Fish']                                                     | fs: 1.00
# ['Beescratch', 'Upbang']                                               | fs: 1.00
# ['Beescratch', 'SN90']                                                 | fs: 1.00
# ['Beescratch', 'SN100']                                                | fs: 1.00
# ['Beescratch', 'Oscar']                                                | fs: 1.00
# ['Beescratch', 'Number1']                                              | fs: 1.00
# ['Beescratch', 'Notch']                                                | fs: 1.00
# ['Beescratch', 'Knit']                                                 | fs: 1.00
# ['Beescratch', 'Jet']                                                  | fs: 1.00
# ['Beak', 'TR77']                                                       | fs: 1.00
# ['Beak', 'SN96']                                                       | fs: 1.00
# ['Beak', 'SN9']                                                        | fs: 1.00
# ['Beak', 'Haecksel']                                                   | fs: 1.00
# ['Beak', 'Grin']                                                       | fs: 1.00
# ['Beak', 'Fish']                                                       | fs: 1.00
# ['Zipfel']                                                             | fs: 1.00
# ['Zig']                                                                | fs: 1.00
# ['Zap']                                                                | fs: 1.00
# ['Whitetip']                                                           | fs: 1.00
# ['Web']                                                                | fs: 1.00
# ['Wave']                                                               | fs: 1.00
# ['Vau']                                                                | fs: 1.00
# ['Upbang']                                                             | fs: 1.00
# ['Trigger']                                                            | fs: 1.00
# ['Topless']                                                            | fs: 1.00
# ['Thumper']                                                            | fs: 1.00
# ['TSN83']                                                              | fs: 1.00
# ['TSN103']                                                             | fs: 1.00
# ['TR99']                                                               | fs: 1.00
# ['TR88']                                                               | fs: 1.00
# ['TR82']                                                               | fs: 1.00
# ['TR77']                                                               | fs: 1.00
# ['TR120']                                                              | fs: 1.00
# ['Stripes']                                                            | fs: 1.00
# ['Shmuddel']                                                           | fs: 1.00
# ['Scabs']                                                              | fs: 1.00
# ['SN96']                                                               | fs: 1.00
# ['SN90']                                                               | fs: 1.00
# ['SN9']                                                                | fs: 1.00
# ['SN89']                                                               | fs: 1.00
# ['SN63']                                                               | fs: 1.00
# ['SN4']                                                                | fs: 1.00
# ['SN100']                                                              | fs: 1.00
# ['SMN5']                                                               | fs: 1.00
# ['Ripplefluke']                                                        | fs: 1.00
# ['Quasi']                                                              | fs: 1.00
# ['Patchback']                                                          | fs: 1.00
# ['PL']                                                                 | fs: 1.00
# ['Oscar']                                                              | fs: 1.00
# ['Number1']                                                            | fs: 1.00
# ['Notch']                                                              | fs: 1.00
# ['Mus']                                                                | fs: 1.00
# ['MN83']                                                               | fs: 1.00
# ['MN60']                                                               | fs: 1.00
# ['MN23']                                                               | fs: 1.00
# ['MN105']                                                              | fs: 1.00
# ['Kringel']                                                            | fs: 1.00
# ['Knit']                                                               | fs: 1.00
# ['Jonah']                                                              | fs: 1.00
# ['Jet']                                                                | fs: 1.00
# ['Hook']                                                               | fs: 1.00
# ['Haecksel']                                                           | fs: 1.00
# ['Grin']                                                               | fs: 1.00
# ['Gallatin']                                                           | fs: 1.00
# ['Fork']                                                               | fs: 1.00
# ['Five']                                                               | fs: 1.00
# ['Fish']                                                               | fs: 1.00
# ['Feather']                                                            | fs: 1.00
# ['Double']                                                             | fs: 1.00
# ['DN63']                                                               | fs: 1.00
# ['DN21']                                                               | fs: 1.00
# ['DN16']                                                               | fs: 1.00
# ['Cross']                                                              | fs: 1.00
# ['CCL']                                                                | fs: 1.00
# ['Bumper']                                                             | fs: 1.00
# ['Beescratch']                                                         | fs: 1.00
# ['Beak']                                                               | fs: 1.00

# %%
# Run the improved algorithm
cliques_improved = find_alpha_cliques(dolphin_graph, alpha, adv_alg=True)
print(f'Number of tested candidate sets (improved): {tcs_improved_counter}')
print(f'Number of {alpha}-cliques (improved): {len(cliques_improved)}')
for clique in cliques_improved:
    print(clique)
# Out:
# Number of tested candidate sets (improved): 574
# Number of 0.8-cliques (improved): 201
# ['Jonah', 'MN105', 'MN83', 'Patchback', 'Topless', 'Trigger']          | fs: 0.80
# ['Grin', 'Hook', 'SN4', 'SN63', 'Scabs', 'Stripes']                    | fs: 0.80
# ['DN21', 'Feather', 'Gallatin', 'SN90', 'Upbang', 'Web']               | fs: 0.80
# ['DN21', 'Feather', 'Gallatin', 'Jet', 'Web']                          | fs: 1.00
# ['DN21', 'Feather', 'Gallatin', 'Jet']                                 | fs: 1.00
# ['DN16', 'Feather', 'Gallatin', 'Web']                                 | fs: 1.00
# ['Beak', 'Fish', 'SN96', 'TR77']                                       | fs: 1.00
# ['SN4', 'Scabs', 'Shmuddel']                                           | fs: 1.00
# ['SN100', 'SN4', 'SN9']                                                | fs: 1.00
# ['Oscar', 'PL', 'TR77']                                                | fs: 1.00
# ['Mus', 'Notch', 'Number1']                                            | fs: 1.00
# ['MN60', 'Topless', 'Trigger']                                         | fs: 1.00
# ['MN105', 'Patchback', 'Topless']                                      | fs: 1.00
# ['Kringel', 'SN63', 'Thumper']                                         | fs: 1.00
# ['Jonah', 'MN105', 'Trigger']                                          | fs: 1.00
# ['Jonah', 'MN105', 'Patchback']                                        | fs: 1.00
# ['Jet', 'Mus', 'Number1']                                              | fs: 1.00
# ['Hook', 'Kringel', 'TR99']                                            | fs: 1.00
# ['Haecksel', 'Topless', 'Zap']                                         | fs: 1.00
# ['Haecksel', 'Jonah', 'MN83']                                          | fs: 1.00
# ['Grin', 'Scabs', 'Shmuddel']                                          | fs: 1.00
# ['Grin', 'SN9', 'TSN103']                                              | fs: 1.00
# ['Grin', 'SN63', 'TSN103']                                             | fs: 1.00
# ['Gallatin', 'SN90', 'Upbang']                                         | fs: 1.00
# ['Feather', 'Gallatin', 'Ripplefluke']                                 | fs: 1.00
# ['Double', 'Topless', 'Zap']                                           | fs: 1.00
# ['Double', 'Kringel', 'Oscar']                                         | fs: 1.00
# ['DN63', 'Knit', 'Upbang']                                             | fs: 1.00
# ['DN63', 'Knit', 'PL']                                                 | fs: 1.00
# ['DN21', 'Feather', 'Jet']                                             | fs: 1.00
# ['DN16', 'Gallatin', 'Web']                                            | fs: 1.00
# ['DN16', 'Feather', 'Web']                                             | fs: 1.00
# ['DN16', 'Feather', 'Gallatin']                                        | fs: 1.00
# ['CCL', 'Double', 'Zap']                                               | fs: 1.00
# ['Bumper', 'Fish', 'SN96']                                             | fs: 1.00
# ['Beescratch', 'Notch', 'Number1']                                     | fs: 1.00
# ['Beescratch', 'Knit', 'Upbang']                                       | fs: 1.00
# ['Beak', 'Haecksel', 'SN9']                                            | fs: 1.00
# ['Beak', 'Fish', 'TR77']                                               | fs: 1.00
# ['Beak', 'Fish', 'SN96']                                               | fs: 1.00
# ['Upbang', 'Web']                                                      | fs: 1.00
# ['Trigger', 'Vau']                                                     | fs: 1.00
# ['Topless', 'Zap']                                                     | fs: 1.00
# ['TSN83', 'Zipfel']                                                    | fs: 1.00
# ['TR99', 'Trigger']                                                    | fs: 1.00
# ['TR82', 'Web']                                                        | fs: 1.00
# ['TR120', 'TR88']                                                      | fs: 1.00
# ['Stripes', 'TSN83']                                                   | fs: 1.00
# ['Stripes', 'TR120']                                                   | fs: 1.00
# ['Shmuddel', 'Thumper']                                                | fs: 1.00
# ['Shmuddel', 'TR88']                                                   | fs: 1.00
# ['Scabs', 'TR99']                                                      | fs: 1.00
# ['Scabs', 'Shmuddel']                                                  | fs: 1.00
# ['SN96', 'TR99']                                                       | fs: 1.00
# ['SN90', 'Upbang']                                                     | fs: 1.00
# ['SN9', 'TSN103']                                                      | fs: 1.00
# ['SN89', 'Web']                                                        | fs: 1.00
# ['SN63', 'Whitetip']                                                   | fs: 1.00
# ['SN63', 'Thumper']                                                    | fs: 1.00
# ['SN63', 'TSN103']                                                     | fs: 1.00
# ['SN63', 'Stripes']                                                    | fs: 1.00
# ['SN4', 'Zipfel']                                                      | fs: 1.00
# ['SN4', 'Shmuddel']                                                    | fs: 1.00
# ['SN100', 'Zap']                                                       | fs: 1.00
# ['SN100', 'SN9']                                                       | fs: 1.00
# ['SN100', 'SN89']                                                      | fs: 1.00
# ['Ripplefluke', 'Zig']                                                 | fs: 1.00
# ['Patchback', 'TSN103']                                                | fs: 1.00
# ['Patchback', 'Stripes']                                               | fs: 1.00
# ['Patchback', 'SMN5']                                                  | fs: 1.00
# ['PL', 'SN96']                                                         | fs: 1.00
# ['Oscar', 'TR77']                                                      | fs: 1.00
# ['Oscar', 'PL']                                                        | fs: 1.00
# ['Mus', 'Number1']                                                     | fs: 1.00
# ['Mus', 'Notch']                                                       | fs: 1.00
# ['MN60', 'Trigger']                                                    | fs: 1.00
# ['MN60', 'Topless']                                                    | fs: 1.00
# ['MN60', 'SN100']                                                      | fs: 1.00
# ['MN105', 'Trigger']                                                   | fs: 1.00
# ['MN105', 'Topless']                                                   | fs: 1.00
# ['MN105', 'Scabs']                                                     | fs: 1.00
# ['MN105', 'Patchback']                                                 | fs: 1.00
# ['Kringel', 'Thumper']                                                 | fs: 1.00
# ['Kringel', 'Oscar']                                                   | fs: 1.00
# ['Knit', 'Upbang']                                                     | fs: 1.00
# ['Knit', 'PL']                                                         | fs: 1.00
# ['Jonah', 'MN105']                                                     | fs: 1.00
# ['Jonah', 'Kringel']                                                   | fs: 1.00
# ['Jet', 'Quasi']                                                       | fs: 1.00
# ['Jet', 'Mus']                                                         | fs: 1.00
# ['Jet', 'MN23']                                                        | fs: 1.00
# ['Hook', 'TR99']                                                       | fs: 1.00
# ['Hook', 'SN63']                                                       | fs: 1.00
# ['Hook', 'Kringel']                                                    | fs: 1.00
# ['Haecksel', 'Zap']                                                    | fs: 1.00
# ['Haecksel', 'Vau']                                                    | fs: 1.00
# ['Haecksel', 'MN83']                                                   | fs: 1.00
# ['Haecksel', 'Jonah']                                                  | fs: 1.00
# ['Grin', 'TSN103']                                                     | fs: 1.00
# ['Grin', 'Shmuddel']                                                   | fs: 1.00
# ['Gallatin', 'SN90']                                                   | fs: 1.00
# ['Gallatin', 'Ripplefluke']                                            | fs: 1.00
# ['Gallatin', 'Jet']                                                    | fs: 1.00
# ['Fork', 'Scabs']                                                      | fs: 1.00
# ['Five', 'Trigger']                                                    | fs: 1.00
# ['Fish', 'TR77']                                                       | fs: 1.00
# ['Fish', 'Patchback']                                                  | fs: 1.00
# ['Feather', 'SN90']                                                    | fs: 1.00
# ['Feather', 'Ripplefluke']                                             | fs: 1.00
# ['Double', 'SN4']                                                      | fs: 1.00
# ['Double', 'Oscar']                                                    | fs: 1.00
# ['DN63', 'SN9']                                                        | fs: 1.00
# ['DN63', 'Number1']                                                    | fs: 1.00
# ['DN63', 'Knit']                                                       | fs: 1.00
# ['DN21', 'Wave']                                                       | fs: 1.00
# ['DN21', 'Jet']                                                        | fs: 1.00
# ['DN21', 'Feather']                                                    | fs: 1.00
# ['DN16', 'Web']                                                        | fs: 1.00
# ['DN16', 'Wave']                                                       | fs: 1.00
# ['DN16', 'Gallatin']                                                   | fs: 1.00
# ['DN16', 'Feather']                                                    | fs: 1.00
# ['Cross', 'Trigger']                                                   | fs: 1.00
# ['CCL', 'Zap']                                                         | fs: 1.00
# ['CCL', 'Grin']                                                        | fs: 1.00
# ['CCL', 'Double']                                                      | fs: 1.00
# ['Bumper', 'Zipfel']                                                   | fs: 1.00
# ['Bumper', 'Thumper']                                                  | fs: 1.00
# ['Bumper', 'SN96']                                                     | fs: 1.00
# ['Bumper', 'Fish']                                                     | fs: 1.00
# ['Beescratch', 'SN90']                                                 | fs: 1.00
# ['Beescratch', 'SN100']                                                | fs: 1.00
# ['Beescratch', 'Oscar']                                                | fs: 1.00
# ['Beescratch', 'Notch']                                                | fs: 1.00
# ['Beescratch', 'Knit']                                                 | fs: 1.00
# ['Beak', 'SN96']                                                       | fs: 1.00
# ['Beak', 'SN9']                                                        | fs: 1.00
# ['Beak', 'Haecksel']                                                   | fs: 1.00
# ['Beak', 'Grin']                                                       | fs: 1.00
# ['Beak', 'Fish']                                                       | fs: 1.00
# ['Zipfel']                                                             | fs: 1.00
# ['Zig']                                                                | fs: 1.00
# ['Zap']                                                                | fs: 1.00
# ['Whitetip']                                                           | fs: 1.00
# ['Web']                                                                | fs: 1.00
# ['Wave']                                                               | fs: 1.00
# ['Vau']                                                                | fs: 1.00
# ['Upbang']                                                             | fs: 1.00
# ['Trigger']                                                            | fs: 1.00
# ['Topless']                                                            | fs: 1.00
# ['Thumper']                                                            | fs: 1.00
# ['TSN83']                                                              | fs: 1.00
# ['TSN103']                                                             | fs: 1.00
# ['TR99']                                                               | fs: 1.00
# ['TR88']                                                               | fs: 1.00
# ['TR82']                                                               | fs: 1.00
# ['TR77']                                                               | fs: 1.00
# ['TR120']                                                              | fs: 1.00
# ['Stripes']                                                            | fs: 1.00
# ['Shmuddel']                                                           | fs: 1.00
# ['Scabs']                                                              | fs: 1.00
# ['SN96']                                                               | fs: 1.00
# ['SN90']                                                               | fs: 1.00
# ['SN9']                                                                | fs: 1.00
# ['SN89']                                                               | fs: 1.00
# ['SN63']                                                               | fs: 1.00
# ['SN4']                                                                | fs: 1.00
# ['SN100']                                                              | fs: 1.00
# ['SMN5']                                                               | fs: 1.00
# ['Ripplefluke']                                                        | fs: 1.00
# ['Quasi']                                                              | fs: 1.00
# ['Patchback']                                                          | fs: 1.00
# ['PL']                                                                 | fs: 1.00
# ['Oscar']                                                              | fs: 1.00
# ['Number1']                                                            | fs: 1.00
# ['Notch']                                                              | fs: 1.00
# ['Mus']                                                                | fs: 1.00
# ['MN83']                                                               | fs: 1.00
# ['MN60']                                                               | fs: 1.00
# ['MN23']                                                               | fs: 1.00
# ['MN105']                                                              | fs: 1.00
# ['Kringel']                                                            | fs: 1.00
# ['Knit']                                                               | fs: 1.00
# ['Jonah']                                                              | fs: 1.00
# ['Jet']                                                                | fs: 1.00
# ['Hook']                                                               | fs: 1.00
# ['Haecksel']                                                           | fs: 1.00
# ['Grin']                                                               | fs: 1.00
# ['Gallatin']                                                           | fs: 1.00
# ['Fork']                                                               | fs: 1.00
# ['Five']                                                               | fs: 1.00
# ['Fish']                                                               | fs: 1.00
# ['Feather']                                                            | fs: 1.00
# ['Double']                                                             | fs: 1.00
# ['DN63']                                                               | fs: 1.00
# ['DN21']                                                               | fs: 1.00
# ['DN16']                                                               | fs: 1.00
# ['Cross']                                                              | fs: 1.00
# ['CCL']                                                                | fs: 1.00
# ['Bumper']                                                             | fs: 1.00
# ['Beescratch']                                                         | fs: 1.00
# ['Beak']                                                               | fs: 1.00

# %%
### Question b

alphas = [0.5, 0.6, 0.7, 0.8]
tcs_basic_counters = []
tcs_improved_counters = []

for alpha in alphas:
    tcs_basic_counter = 0
    cliques = find_alpha_cliques(dolphin_graph, alpha)
    tcs_basic_counters.append(tcs_basic_counter)
    
    tcs_improved_counter = 0
    cliques_improved = find_alpha_cliques(dolphin_graph, alpha, adv_alg=True)
    tcs_improved_counters.append(tcs_improved_counter)


# Plot the number of tested candidate sets across different alpha values
# for both basic and improved algorithms
plt.figure(figsize=(10, 6))
plt.plot(alphas, tcs_basic_counters, '-o', label='Basic Algorithm')
plt.plot(alphas, tcs_improved_counters, '-o', label='Improved Algorithm')
plt.xlabel('Alpha')
plt.ylabel('Number of tested candidate sets')
plt.title('Number of tested candidate sets across different alpha values')
plt.legend()
plt.grid()
plt.show()

# %%
for alpha in alphas:
    tcs_basic_counter = 0
    cliques = find_alpha_cliques(dolphin_graph, alpha)
    tcs_basic_counters.append(tcs_basic_counter)
    
    tcs_improved_counter = 0
    cliques_improved = find_alpha_cliques(dolphin_graph, alpha, adv_alg=True)
    tcs_improved_counters.append(tcs_improved_counter)

# Print the table headerl
print(f"{'Alpha':<10} {'Basic Algorithm':<20} {'Improved Algorithm':<20}")
print("-" * 50)

# Print each row of the table
for alpha, basic_count, improved_count in zip(alphas, tcs_basic_counters, tcs_improved_counters):
    print(f"{alpha:<10} {basic_count:<20} {improved_count:<20}")
# Out:
# Alpha      Basic Algorithm      Improved Algorithm
# --------------------------------------------------
# 0.5        1613                 1471
# 0.6        1261                 1127
# 0.7        1006                 902
# 0.8        621                  574

# %%
# Question c
# Search the maximal alpha-cliques when alpha = 0.8 and the set size is at least 5
alpha = 0.8
min_set_size = 5

cliques_improved = find_alpha_cliques(dolphin_graph, alpha, adv_alg=True)
maximal_cliques = [clique for clique in cliques_improved if len(clique) >= min_set_size]
for i, cli in enumerate(maximal_cliques, start=1):
    print(f'{i}: {cli}')
# Out:
# 1: ['Jonah', 'MN105', 'MN83', 'Patchback', 'Topless', 'Trigger']          | fs: 0.80
# 2: ['Grin', 'Hook', 'SN4', 'SN63', 'Scabs', 'Stripes']                    | fs: 0.80
# 3: ['DN21', 'Feather', 'Gallatin', 'SN90', 'Upbang', 'Web']               | fs: 0.80
# 4: ['DN21', 'Feather', 'Gallatin', 'Jet', 'Web']                          | fs: 1.00

# %%
# Investigate the gender distribution of the maximal alpha-cliques
clique_gender_distribution = []
for clique in maximal_cliques:
    gender_count = {gender: 0 for gender in set(dolphin_dict.values())}
    for dolphin in clique:
        gender_count[dolphin_dict[dolphin]] += 1
    clique_gender_distribution.append(gender_count)

for i, gender_count in enumerate(clique_gender_distribution, start=1):
    labels = ['Male', 'Female', 'Unspecified']
    values = [gender_count['M'], gender_count['F'], gender_count['U']]

    clique = maximal_cliques[i-1].nodes

    # Bar chart
    plt.figure(figsize=(7, 4))
    plt.bar(labels, values, color=['blue', 'pink', 'grey'])
    plt.title(f"Maximal {alpha}-clique {i}\n{clique}")
    plt.ylabel("Count")
    plt.xlabel("Gender")
    plt.show()
