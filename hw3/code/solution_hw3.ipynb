# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Numerical features engineering
#
# ### Data Summary

# %%
data = pd.read_csv('birds2024ext.csv', delimiter=';')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   species       50 non-null     object
#  1   group         50 non-null     object
#  2   length        50 non-null     object
#  3   wspan         50 non-null     object
#  4   weight        50 non-null     object
#  5   AR            50 non-null     float64
#  6   wload         50 non-null     float64
#  7   back          50 non-null     object
#  8   belly         50 non-null     object
#  9   ftype         50 non-null     object
#  10  sim           50 non-null     object
#  11  billcol       50 non-null     object
#  12  legcol        50 non-null     object
#  13  arrives       50 non-null     object
#  14  leaves        50 non-null     object
#  15  eggs          50 non-null     object
#  16  incub         50 non-null     object
#  17  ccare         50 non-null     object
#  18  biotope       50 non-null     object
#  19  diet          50 non-null     object
#  20  diver         50 non-null     object
#  21  long-billed   50 non-null     object
#  22  webbed-feet   50 non-null     object
#  23  long-legs     50 non-null     object
#  24  wading-bird   50 non-null     object
#  25  plunge-dives  50 non-null     object
# dtypes: float64(2), object(24)
# memory usage: 10.3+ KB

# %%
data.T.iloc[:, :20]
# Out:
#                                       0                          1   \
# species                       naurulokki                harmaalokki
# group                            laridae                    laridae
# length                             34-38                      55-65
# wspan                              86-99                    123-148
# weight                           200-350                   800-1300
# AR                                  8.13                       8.24
# wload                               0.31                       0.64
# back                          light grey                bluish grey
# belly                              white                      white
# ftype                                  B                          B
# sim                                  Yes                        Yes
# billcol                              red                     yellow
# legcol                               red                    reddish
# arrives                      March-April                March-April
# leaves                              July            August-December
# eggs                                 1-3                        1-3
# incub                               both                       both
# ccare                               both                       both
# biotope                   lakes,sea-bays  lakes,sea-coast,marshland
# diet          fish,invertebrates,garbage  fish,garbage,chicks,grain
# diver                                 No                         No
# long-billed                           No                         No
# webbed-feet                          Yes                        Yes
# long-legs                             No                         No
# wading-bird                           No                         No
# plunge-dives                         Yes                        Yes
#
#                                             2                  3   \
# species                               isolokki          kalatiira
# group                                  laridae          sternidae
# length                                   63-68              36-42
# wspan                                  138-158              70-80
# weight                               1000-1800            100-145
# AR                                        8.24               9.14
# wload                                     0.66               0.24
# back                               bluish grey               grey
# belly                                    white              white
# ftype                                        B                  B
# sim                                        Yes                Yes
# billcol                                 yellow                red
# legcol                                 reddish                red
# arrives                               December                May
# leaves                                   March   August-September
# eggs                                         3                1-3
# incub                                     both               both
# ccare                                     both               both
# biotope                    sea-coast, harbours  lakes,archipelago
# diet          fish,eggs,chicks,garbage,carrion               fish
# diver                                       No                 No
# long-billed                                 No                 No
# webbed-feet                                Yes                Yes
# long-legs                                   No                 No
# wading-bird                                 No                 No
# plunge-dives                               Yes                Yes
#
#                                        4                    5   \
# species                        lapintiira             suokukko
# group                           sternidae         scolopacidae
# length                              33-37                25-26
# wspan                               66-77                46-49
# weight                             90-130               90-130
# AR                                   8.97                 6.73
# wload                                 0.2                 0.36
# back                                 grey        dappled brown
# belly                               white                white
# ftype                                   B                    C
# sim                                   Yes                   No
# billcol                               red           dark-brown
# legcol                                red               orange
# arrives                               May            April-May
# leaves                        July-August            June-July
# eggs                                  1-3                    4
# incub                                both                    F
# ccare                                both                    F
# biotope       archipelago,lakes,marshland   marshland,wetlands
# diet                                 fish  invertebrates,seeds
# diver                                  No                   No
# long-billed                            No                   No
# webbed-feet                           Yes                   No
# long-legs                              No                  Yes
# wading-bird                            No                  Yes
# plunge-dives                          Yes                   No
#
#                                      6                                  7   \
# species                    taivaanvuohi                        lehtokurppa
# group                      scolopacidae                       scolopacidae
# length                            25-27                              34-36
# wspan                             39-45                              55-65
# weight                           90-110                            280-330
# AR                                 5.91                               5.68
# wload                               0.4                               0.54
# back                      dappled brown                      dappled brown
# belly                             white                      dappled beige
# ftype                                 C                                  C
# sim                                 Yes                                Yes
# billcol                   reddish-brown                              brown
# legcol                    greenish-grey                     yellowish-grey
# arrives                       April-May                        March-April
# leaves                   August-October                  September-October
# eggs                                  4                                  4
# incub                                 F                                  F
# ccare                                 F                                  F
# biotope       marshland,coastal-meadows                            forests
# diet                      invertebrates  invertebrates,worms,larvae,snails
# diver                                No                                 No
# long-billed                         Yes                                Yes
# webbed-feet                          No                                 No
# long-legs                            No                                 No
# wading-bird                         Yes                                Yes
# plunge-dives                         No                                 No
#
#                                 8                   9                   10  \
# species                 metsäviklo                liro           karikukko
# group                 scolopacidae        scolopacidae        scolopacidae
# length                       21-24               21-23               21-24
# wspan                        39-44               35-39               43-49
# weight                       75-85               50-70              90-130
# AR                             7.2                7.53                7.21
# wload                         0.29                0.23                0.45
# back                         brown       dappled brown         black-brown
# belly                        white               white               white
# ftype                            C                   C                   C
# sim                            Yes                 Yes                 Yes
# billcol                      black               black               black
# legcol               greenish-grey     greenish-yellow              orange
# arrives                March-April                 May           April-May
# leaves                   June-July      June-September         July-August
# eggs                             4                   4                   4
# incub                         both                both                both
# ccare                            M                   M                   M
# biotope              forests,ponds  marshland,wetlands  archipelago,islets
# diet          invertebrates,plants       invertebrates  invertebrates,eggs
# diver                           No                  No                  No
# long-billed                    Yes                 Yes                  No
# webbed-feet                     No                  No                  No
# long-legs                      Yes                 Yes                  No
# wading-bird                    Yes                 Yes                 Yes
# plunge-dives                    No                  No                  No
#
#                                     11                            12  \
# species                       suosirri                    pikkusirri
# group                     scolopacidae                  scolopacidae
# length                           17-21                         14-16
# wspan                            32-36                         27-30
# weight                           35-62                         20-30
# AR                                6.95                          6.63
# wload                             0.31                          0.18
# back                     dappled brown                 dappled brown
# belly                      black-white                         white
# ftype                                C                             C
# sim                                Yes                           Yes
# billcol                          black                         black
# legcol                           black                         black
# arrives                     March-June                      May-June
# leaves                    July-October                July-September
# eggs                                 4                             4
# incub                             both                          both
# ccare                             both                          both
# biotope       coastal-meadows,wetlands  shores,wetlands,shrub-tundra
# diet                     invertebrates                 invertebrates
# diver                               No                            No
# long-billed                        Yes                            No
# webbed-feet                         No                            No
# long-legs                           No                            No
# wading-bird                        Yes                           Yes
# plunge-dives                        No                            No
#
#                           13                    14                     15  \
# species           pikkutylli                 tylli           keräkurmitsa
# group           charadriidae          charadriidae           charadriidae
# length                 15-16                 18-19                  20-24
# wspan                  32-35                 35-41                  57-64
# weight                 35-45                 50-65                 85-140
# AR                      6.93                  7.43                   7.43
# wload                   0.24                  0.32                   0.45
# back           greyish brown         greyish brown          dappled brown
# belly                  white                 white                  black
# ftype                      C                     C                      C
# sim                      Yes                   Yes                    Yes
# billcol                black                orange                  black
# legcol              brownish                orange                 yellow
# arrives            April-May           March-April               May-June
# leaves           July-August          July-October       August-September
# eggs                       4                     4                      3
# incub                   both                  both                      M
# ccare                   both                  both                      M
# biotope               shores                shores                  fells
# diet          insects,snails  invertebrates,snails  insects,worms,berries
# diver                     No                    No                     No
# long-billed               No                    No                     No
# webbed-feet               No                    No                     No
# long-legs                 No                    No                     No
# wading-bird              Yes                   Yes                    Yes
# plunge-dives              No                    No                     No
#
#                          16                      17                    18  \
# species        töyhtöhyyppä                 haapana                  tavi
# group          charadriidae          dabbling ducks        dabbling ducks
# length                30-34                   41-51                 34-38
# wspan                 67-72                   71-80                 53-59
# weight              170-230                 600-800               250-450
# AR                     5.45                     7.7                  6.51
# wload                  0.34                    1.09                  0.75
# back                  black           dappled brown         dappled brown
# belly                 white                   white                 beige
# ftype                     C                       C                     C
# sim                     Yes                      No                    No
# billcol               black                    grey                  grey
# legcol         brownish-red                    grey         greenish-grey
# arrives         March-April               March-May             April-May
# leaves        June-November          August-October      August-September
# eggs                      4                     7-9                  7-11
# incub                  both                       F                     F
# ccare                  both                       F                     F
# biotope              fields  lakes,marshland,shores   lakes,ponds,streams
# diet          worms,insects                  plants  plants,invertebrates
# diver                    No                      No                    No
# long-billed              No                      No                    No
# webbed-feet              No                     Yes                   Yes
# long-legs                No                      No                    No
# wading-bird             Yes                      No                    No
# plunge-dives             No                      No                    No
#
#                                 19
# species                  sinisorsa
# group               dabbling ducks
# length                       50-60
# wspan                        79-87
# weight                    900-1300
# AR                            6.19
# wload                         1.05
# back                 dappled brown
# belly                        beige
# ftype                            C
# sim                             No
# billcol                     orange
# legcol                      orange
# arrives                March-April
# leaves            October-November
# eggs                          5-12
# incub                            F
# ccare                            F
# biotope               lakes,shores
# diet          plants,invertebrates
# diver                           No
# long-billed                     No
# webbed-feet                    Yes
# long-legs                       No
# wading-bird                     No
# plunge-dives                    No

# %% [markdown]
# ## Iteration-1 features
#
# start with the habitat, group, diet as the first features.

# %%
def extract_features(df, feature_list):
    df_return = df[feature_list].copy()
    return df_return

# %%
# More descriptive naming
feature_list = ['group', 'biotope', 'diet']
feature_subset = extract_features(data, feature_list=feature_list)
feature_subset.head(5)
# Out:
#        group                      biotope                              diet
# 0    laridae               lakes,sea-bays        fish,invertebrates,garbage
# 1    laridae    lakes,sea-coast,marshland         fish,garbage,chicks,grain
# 2    laridae          sea-coast, harbours  fish,eggs,chicks,garbage,carrion
# 3  sternidae            lakes,archipelago                              fish
# 4  sternidae  archipelago,lakes,marshland                              fish

# %%
# Check for NaNs
print("NaNs in 'group':", feature_subset['group'].isna().sum())
print("NaNs in 'biotope':", feature_subset['biotope'].isna().sum())
print("NaNs in 'diet':", feature_subset['diet'].isna().sum())

# Check for empty strings
print("Empty strings in 'group':", (feature_subset['group'] == '').sum())
print("Empty strings in 'biotope':", (feature_subset['biotope'] == '').sum())
print("Empty strings in 'diet':", (feature_subset['diet'] == '').sum())
# Out:
# NaNs in 'group': 0
# NaNs in 'biotope': 0
# NaNs in 'diet': 0
# Empty strings in 'group': 0
# Empty strings in 'biotope': 0
# Empty strings in 'diet': 0

# %%
# Function to clean categorical columns
def clean_column(df, column, delimiter=','):
    """
    Cleans a categorical column by:
    - Stripping whitespace
    - Converting to lowercase
    - Standardizing delimiters
    """
    # Remove leading/trailing whitespace and convert to lowercase
    df.loc[:, column] = df[column].str.strip().str.lower()
    
    # Replace multiple spaces with single space using a raw string
    df.loc[:, column] = df[column].str.replace(r'\s+', ' ', regex=True)
    
    # Ensure consistent delimiter spacing
    df.loc[:, column] = df[column].str.replace(f' {delimiter}', delimiter, regex=False)
    df.loc[:, column] = df[column].str.replace(f'{delimiter} ', delimiter, regex=False)
    
    return df


def count_unique_items(df, columns):
    """
    Counts the number of unique items in each specified column of the DataFrame,
    considering that some cell values contain comma-separated items.

    Parameters:
    - df (pd.DataFrame): The DataFrame containing the data.
    - columns (list): List of column names to analyze.

    Returns:
    - dict: A dictionary with column names as keys and unique counts as values.
    """
    unique_counts = {}
    for column in columns:
        unique_items = set()
        for items in df[column].dropna():
            # Split the string by commas and strip whitespace
            split_items = [item.strip() for item in items.split(',')]
            unique_items.update(split_items)
        unique_counts[column] = len(unique_items)
    return unique_counts

# %%
# Calculate unique counts

cols = feature_subset.columns.tolist()[1:]
# Apply cleaning to each categorical column
for column in cols:
    feature_subset = clean_column(feature_subset, column)

unique_counts = count_unique_items(feature_subset, cols)
sum = 0



# Print unique counts
print("\nNumber of Unique Values in Each Column:")
for column, count in unique_counts.items():
    sum += count
    print(f"Column '{column}': {count} unique value(s)")
print(f"total count: {sum} for columns {cols}")
# Out:
# Number of Unique Values in Each Column:
# Column 'biotope': 21 unique value(s)
# Column 'diet': 28 unique value(s)
# total count: 49 for columns ['biotope', 'diet']

# %% [markdown]
# ### One-Hot Encoding
#
# The Apriori algorithm needs the data to be in a 1 hot encoded format with binary values for each feature. thus the 3 features are now subdivided into binary features
#
#
#
# go through groups, if not in array, add it.
# then loop through that arr, and add that to columns.
# then loop through data and add 1 to that col if group is that
# then delete group column
#
#
# pd.concat() in pandas is used to concatenate two or more DataFrames or Series along a particular axis (either rows or columns). You can specify how you want to join the data (e.g., along rows or columns) and whether to keep all data or just the common parts.

# %%
def one_hot_encode_column(df: pd.DataFrame, column: str, unique: bool) -> pd.DataFrame:
    """ 
    encodes the selected column as a binary valued columns

    Parameters:
    - df (pd.DataFrame): The DataFrame containing the data.
    - column: column to process
    - unique (bool): if the column has unique values

    Returns:
    - pd.DataFrame: DataFrame with the original column dropped and new one-hot encoded columns added.
    """
    if column not in df.columns:
        raise ValueError(f"Column '{column}' does not exist in the DataFrame.")

    if unique:
        group_dummies = pd.get_dummies(df[column], prefix=column)
    else: 
        group_dummies = df[column].str.get_dummies(sep=',').rename(columns=lambda x: f'{column}_{x.strip()}')
        group_dummies = group_dummies.astype(bool)
    

    encoded_features = pd.concat([df.drop(columns=[column]), group_dummies], axis=1)
    return encoded_features

# %%
pd.set_option('display.max_rows', None)  # This will show all rows
encoded_features = feature_subset.copy()

encoded_features = one_hot_encode_column(encoded_features, 'group', unique=True)

for col in ['biotope', 'diet']:
    encoded_features = one_hot_encode_column(encoded_features, col, unique=False)



print("encoded_features.head(1).T.shape", " : " , encoded_features.head(1).T.shape)
# Out:
# encoded_features.head(1).T.shape  :  (63, 1)

# %% [markdown]
# ### Since association rules are not monotonic, we could find interesting rules by looking at the family of the birds.

# %%
# Assuming 'encoded_features' is the DataFrame that contains the one-hot encoded columns
species_columns = [col for col in encoded_features.columns if col.startswith('group_')]



taxonomy_mapping = {
    'group_laridae': '1.1 Lari',
    'group_sternidae': '1.1 Lari',
    'group_scolopacidae': '1.2 Charadrii',
    'group_charadriidae': '1.2 Charadrii',
    'group_haematopodidae': '1.2 Charadrii',
    'group_dabbling ducks': '2.1 Anatinae',
    'group_diving ducks': '2.1 Anatinae'
}

print("len(taxonomy_mapping)", " " , len(taxonomy_mapping))
print(species_columns)
print(len(species_columns))
# Out:
# len(taxonomy_mapping)   7
# ['group_accipitridae', 'group_anserinae', 'group_ardeidae', 'group_charadriidae', 'group_dabbling ducks', 'group_diving ducks', 'group_gaviidae', 'group_gruifores', 'group_laridae', 'group_phalacrocoracidae', 'group_podicipedidae', 'group_rallidae', 'group_scolopacidae', 'group_sternidae']
# 14

# %%
# Function to map the general group based on the true column
def map_general_group(row):
    for col in species_columns:
        if row[col]:  # Check if the group is True
            return taxonomy_mapping.get(col, None)  # Map to general group
    return None

# %% [markdown]
# ### Adding the general family column

# %%
# Apply the mapping to create the new column 'general_group'
encoded_features['family'] = encoded_features.apply(map_general_group, axis=1)
encoded_features = one_hot_encode_column(encoded_features, 'family', unique= True)

# encoded_features.T.iloc[encoded_features.shape[1] - 5: encoded_features.shape[1]+ 1, :3]
encoded_features.T.iloc[encoded_features.shape[1] - 12: encoded_features.shape[1]+ 1, :3]

pd.reset_option('display.max_rows')

# encoded_features.T.iloc[-15:, :4]

# %% [markdown]
# ### Iteration-1 Apriori
# ### Apriori Algorithm

# %% [markdown]
# ### Support
#
# The support of an itemset \( X \) is defined as:
#
# $$
# \text{Support}(X) = \frac{\text{Number of transactions containing } X}{\text{Total number of transactions}}
# $$
#
# ### Confidence
#
# The confidence of an association rule \( X \rightarrow Y \) is defined as:
# $$
# \text{Confidence}(X \rightarrow Y) = \frac{\text{Support}(X \cup Y)}{\text{Support}(X)} = P(Y \mid X)
# $$
#
# ### Lift
#
# The lift of an association rule \( X \rightarrow Y \) is defined as:
# $$
# \text{Lift}(X \rightarrow Y) = \frac{\text{Confidence}(X \rightarrow Y)}{\text{Support}(Y)} = \frac{P(Y \mid X)}{P(Y)}
# $$
#
# Alternatively, it can be expressed as:
# $$
# \text{Lift}(X \rightarrow Y) = \frac{\text{Support}(X \cup Y)}{\text{Support}(X) \times \text{Support}(Y)} = \frac{P(Y \mid X)}{P(Y)}
# $$

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
def filter_rules(rules_df: pd.DataFrame, min_lift: float = 1.0, min_support: float = 0.0, 
                min_confidence: float = 0.0, max_rules: int = 100, special_sorting: bool = True) -> pd.DataFrame:
    """
    Filters and sorts association rules based on lift, support, and confidence thresholds.

    Parameters:
    - rules_df (pd.DataFrame): DataFrame containing association rules.
    - min_lift (float): Minimum lift threshold.
    - min_support (float): Minimum support threshold.
    - min_confidence (float): Minimum confidence threshold.
    - max_rules (int): Maximum number of rules to return.

    Returns:
    - pd.DataFrame: Filtered and sorted association rules.
    """
    # Apply multiple filters
    filtered_rules = rules_df[
        (rules_df['lift'] >= min_lift) &
        (rules_df['support'] >= min_support) &
        (rules_df['confidence'] >= min_confidence)
    ].copy()

    if special_sorting: # Ensure you're modifying the DataFrame in place using .loc
        filtered_rules.loc[:,'combined_product'] = filtered_rules['lift'] * (1/4) * filtered_rules['confidence'] * filtered_rules['support'] * filtered_rules['zhangs_metric']
        sorted_rules = filtered_rules.sort_values(
            by=['combined_product'], 
            ascending=[False]
        )
    else: # Sort rules by lift descending, then by support descending, then by confidence descending
        sorted_rules = filtered_rules.sort_values(
            by=['lift', 'support', 'confidence'], 
            ascending=[False, False, False]
        )
    
    # Remove duplicate rules based on antecedents and consequents
    sorted_rules = sorted_rules.drop_duplicates(subset=['antecedents', 'consequents'])
    # print("len(sorted_rules)" , " " , len(sorted_rules))
    # print("len(rules_df)" , " " , len(rules_df))

    # Return the top max_rules
    return sorted_rules.head(max_rules)


def output_rules_apriori(df: pd.DataFrame, min_lift: float = 1.0, min_support: float = 0.07, 
                min_confidence: float = 0.0, max_rules: int = 15):


    frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
    filtered_rules = filter_rules(rules, min_lift=min_lift, min_support=min_support, min_confidence=min_confidence, max_rules=max_rules)

    return filtered_rules

# %%
# Define minimum support (e.g., 0.05 for 5%)
frequent_itemsets = apriori(encoded_features, min_support=0.05, use_colnames=True)

# Sort by support
frequent_itemsets = frequent_itemsets.sort_values(by='support', ascending=False)
print(len(frequent_itemsets))
frequent_itemsets.head(10)
# Out:
# 197
#      support                                    itemsets
# 31      0.36                        (diet_invertebrates)
# 12      0.34                             (biotope_lakes)
# 26      0.32                                 (diet_fish)
# 30      0.26                              (diet_insects)
# 32      0.26                               (diet_plants)
# 40      0.24                      (family_1.2 Charadrii)
# 80      0.20                  (diet_fish, biotope_lakes)
# 35      0.20                        (diet_small-rodents)
# 18      0.18                          (biotope_sea-bays)
# 123     0.18  (diet_invertebrates, family_1.2 Charadrii)

# %%
output_rules_apriori(df = encoded_features)
# Out:
#                                                                                                                                                                                                                antecedents  \
# 58                                                                                                                       f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\ng\nr\no\nu\np\n_\ns\nc\no\nl\no\np\na\nc\ni\nd\na\ne\n'\n}\n)
# 55                                              f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\ni\nn\nv\ne\nr\nt\ne\nb\nr\na\nt\ne\ns\n'\n\n\n \n'\nf\na\nm\ni\nl\ny\n_\n1\n.\n2\n \nC\nh\na\nr\na\nd\nr\ni\ni\n'\n}\n)
# 95   f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nd\ni\ne\nt\n_\ni\nn\nv\ne\nr\nt\ne\nb\nr\na\nt\ne\ns\n'\n\n\n \n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 42                                                 f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\ni\nn\nv\ne\nr\nt\ne\nb\nr\na\nt\ne\ns\n'\n\n\n \n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 35                                                             f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nb\ni\no\nt\no\np\ne\n_\ns\nh\no\nr\ne\ns\n'\n\n\n \n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 31                                                                                     f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nb\ni\no\nt\no\np\ne\n_\ns\nh\no\nr\ne\ns\n'\n}\n)
# 85               f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nb\ni\no\nt\no\np\ne\n_\ns\nh\no\nr\ne\ns\n'\n\n\n \n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 89                                                                                     f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nb\ni\no\nt\no\np\ne\n_\ns\nh\no\nr\ne\ns\n'\n}\n)
# 100                                                f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\ni\nn\nv\ne\nr\nt\ne\nb\nr\na\nt\ne\ns\n'\n\n\n \n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 91                                                             f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nb\ni\no\nt\no\np\ne\n_\ns\nh\no\nr\ne\ns\n'\n\n\n \n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 47                                                                   f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\ng\nr\no\nu\np\n_\nd\na\nb\nb\nl\ni\nn\ng\n \nd\nu\nc\nk\ns\n'\n}\n)
# 50                                                                                                                 f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\ng\nr\no\nu\np\n_\nd\na\nb\nb\nl\ni\nn\ng\n \nd\nu\nc\nk\ns\n'\n}\n)
# 8                                                                                                                  f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\ng\nr\no\nu\np\n_\nd\na\nb\nb\nl\ni\nn\ng\n \nd\nu\nc\nk\ns\n'\n}\n)
# 45                                                                                                                 f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\ng\nr\no\nu\np\n_\nd\na\nb\nb\nl\ni\nn\ng\n \nd\nu\nc\nk\ns\n'\n}\n)
# 94                                                                                                                 f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\ng\nr\no\nu\np\n_\nd\na\nb\nb\nl\ni\nn\ng\n \nd\nu\nc\nk\ns\n'\n}\n)
#
#                                           consequents  antecedent support  \
# 58           diet_invertebrates\nfamily_1.2 Charadrii                0.16
# 55                                 group_scolopacidae                0.18
# 95                               group_dabbling ducks                0.08
# 42                               group_dabbling ducks                0.08
# 35                               group_dabbling ducks                0.08
# 31                               group_dabbling ducks                0.08
# 85                               group_dabbling ducks                0.08
# 89          family_2.1 Anatinae\ngroup_dabbling ducks                0.08
# 100                 diet_plants\ngroup_dabbling ducks                0.08
# 91                  diet_plants\ngroup_dabbling ducks                0.08
# 47                                family_2.1 Anatinae                0.10
# 50                   diet_plants\nfamily_2.1 Anatinae                0.10
# 8                                 family_2.1 Anatinae                0.10
# 45            diet_invertebrates\nfamily_2.1 Anatinae                0.10
# 94   diet_plants\nbiotope_shores\nfamily_2.1 Anatinae                0.10
#
#      consequent support  support  confidence       lift  leverage  conviction  \
# 58                 0.18     0.16    1.000000   5.555556    0.1312         inf
# 55                 0.16     0.16    0.888889   5.555556    0.1312        7.56
# 95                 0.10     0.08    1.000000  10.000000    0.0720         inf
# 42                 0.10     0.08    1.000000  10.000000    0.0720         inf
# 35                 0.10     0.08    1.000000  10.000000    0.0720         inf
# 31                 0.10     0.08    1.000000  10.000000    0.0720         inf
# 85                 0.10     0.08    1.000000  10.000000    0.0720         inf
# 89                 0.10     0.08    1.000000  10.000000    0.0720         inf
# 100                0.10     0.08    1.000000  10.000000    0.0720         inf
# 91                 0.10     0.08    1.000000  10.000000    0.0720         inf
# 47                 0.14     0.10    1.000000   7.142857    0.0860         inf
# 50                 0.14     0.10    1.000000   7.142857    0.0860         inf
# 8                  0.14     0.10    1.000000   7.142857    0.0860         inf
# 45                 0.08     0.08    0.800000  10.000000    0.0720        4.60
# 94                 0.08     0.08    0.800000  10.000000    0.0720        4.60
#
#      zhangs_metric  combined_product
# 58        0.976190          0.216931
# 55        1.000000          0.197531
# 95        0.978261          0.195652
# 42        0.978261          0.195652
# 35        0.978261          0.195652
# 31        0.978261          0.195652
# 85        0.978261          0.195652
# 89        0.978261          0.195652
# 100       0.978261          0.195652
# 91        0.978261          0.195652
# 47        0.955556          0.170635
# 50        0.955556          0.170635
# 8         0.955556          0.170635
# 45        1.000000          0.160000
# 94        1.000000          0.160000

# %% [markdown]
# ## Iteration-2
# ## Introduction of more features

# %%
def boolean_encode_column(df: pd.DataFrame, column: str) -> pd.DataFrame:
    """ 
    turns the yes no columns to boolean
    """
    df[column] = df[column].map({'Yes': True, 'No': False})
    return df

def add_new_columns(data: pd.DataFrame, df: pd.DataFrame, columns: list[str], booleanize: bool = True) -> pd.DataFrame:
    """ 
    adds a new column and turns that into boolean values.map
    """
    
    for col in columns:
        if col not in data.columns:
            raise ValueError (f"Column '{col}' does not exist in the DataFrame.")

        df[col] = data[col]
        if booleanize:
            boolean_encode_column(df, col)

    return df

# %%
data['non_sim'] = data['sim'].map({'Yes': 'No', 'No': 'Yes'})

binary_encoded_columns = ['sim','non_sim' , 'diver', 'long-billed', 'webbed-feet', 'long-legs', 'wading-bird', 'plunge-dives']


add_new_columns(data, encoded_features, binary_encoded_columns)

encoded_features.T.iloc[:, 10:30]
# Out:
#                          10     11     12     13     14     15     16     17  \
# group_accipitridae    False  False  False  False  False  False  False  False
# group_anserinae       False  False  False  False  False  False  False  False
# group_ardeidae        False  False  False  False  False  False  False  False
# group_charadriidae    False  False  False   True   True   True   True  False
# group_dabbling ducks  False  False  False  False  False  False  False   True
# ...                     ...    ...    ...    ...    ...    ...    ...    ...
# long-billed           False   True  False  False  False  False  False  False
# webbed-feet           False  False  False  False  False  False  False   True
# long-legs             False  False  False  False  False  False  False  False
# wading-bird            True   True   True   True   True   True   True  False
# plunge-dives          False  False  False  False  False  False  False  False
#
#                          18     19     20     21     22     23     24     25  \
# group_accipitridae    False  False  False  False  False  False  False  False
# group_anserinae       False  False  False  False  False  False   True   True
# group_ardeidae        False  False  False  False  False  False  False  False
# group_charadriidae    False  False  False  False  False  False  False  False
# group_dabbling ducks   True   True   True   True  False  False  False  False
# ...                     ...    ...    ...    ...    ...    ...    ...    ...
# long-billed           False  False  False  False  False  False  False  False
# webbed-feet            True   True   True   True   True   True   True   True
# long-legs             False  False  False  False  False  False  False  False
# wading-bird           False  False  False  False  False  False  False  False
# plunge-dives          False  False  False  False  False  False  False  False
#
#                          26     27     28     29
# group_accipitridae    False  False  False  False
# group_anserinae       False  False  False  False
# group_ardeidae        False  False  False  False
# group_charadriidae    False  False  False  False
# group_dabbling ducks  False  False  False  False
# ...                     ...    ...    ...    ...
# long-billed            True   True  False  False
# webbed-feet           False  False  False  False
# long-legs              True   True   True   True
# wading-bird            True   True   True   True
# plunge-dives          False  False  False  False
#
# [74 rows x 20 columns]

# %% [markdown]
# ### Iteration-2 Apriori

# %%
output_rules_apriori(df = encoded_features)
# Out:
#                                                                                                                                                                 antecedents  \
# 1700  f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nw\na\nd\ni\nn\ng\n-\nb\ni\nr\nd\n'\n\n\n \n'\nd\ni\ne\nt\n_\ns\nm\na\nl\nl\n-\nr\no\nd\ne\nn\nt\ns\n'\n\n\n \n'\ns\ni\nm\n'\n}\n)
# 1110                                                                   f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 1052                        f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\ns\nm\na\nl\nl\n-\nr\no\nd\ne\nn\nt\ns\n'\n\n\n \n'\nl\no\nn\ng\n-\nb\ni\nl\nl\ne\nd\n'\n}\n)
# 1053                                                f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\nf\nr\no\ng\ns\n'\n\n\n \n'\nl\no\nn\ng\n-\nb\ni\nl\nl\ne\nd\n'\n}\n)
# 1099           f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nn\no\nn\n_\ns\ni\nm\n'\n\n\n \n'\nw\ne\nb\nb\ne\nd\n-\nf\ne\ne\nt\n'\n}\n)
# 1103                                                         f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nn\no\nn\n_\ns\ni\nm\n'\n}\n)
# 1105                     f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 1106                                                         f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nn\no\nn\n_\ns\ni\nm\n'\n\n\n \n'\nw\ne\nb\nb\ne\nd\n-\nf\ne\ne\nt\n'\n}\n)
# 454                                                                    f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 1108                     f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nw\ne\nb\nb\ne\nd\n-\nf\ne\ne\nt\n'\n\n\n \n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 397                                                          f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nn\no\nn\n_\ns\ni\nm\n'\n}\n)
# 1050                        f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nw\na\nd\ni\nn\ng\n-\nb\ni\nr\nd\n'\n\n\n \n'\nd\ni\ne\nt\n_\ns\nm\na\nl\nl\n-\nr\no\nd\ne\nn\nt\ns\n'\n}\n)
# 401                                                                    f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 1703                          f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nw\na\nd\ni\nn\ng\n-\nb\ni\nr\nd\n'\n\n\n \n'\ns\ni\nm\n'\n\n\n \n'\nd\ni\ne\nt\n_\nf\nr\no\ng\ns\n'\n}\n)
# 1705  f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\ns\nm\na\nl\nl\n-\nr\no\nd\ne\nn\nt\ns\n'\n\n\n \n'\ns\ni\nm\n'\n\n\n \n'\nl\no\nn\ng\n-\nb\ni\nl\nl\ne\nd\n'\n}\n)
#
#                             consequents  antecedent support  \
# 1700            diet_frogs\nlong-billed                0.08
# 1110  diet_plants\nnon_sim\nwebbed-feet                0.14
# 1052            wading-bird\ndiet_frogs                0.08
# 1053    wading-bird\ndiet_small-rodents                0.08
# 1099                family_2.1 Anatinae                0.14
# 1103   webbed-feet\nfamily_2.1 Anatinae                0.14
# 1105               non_sim\nwebbed-feet                0.14
# 1106   diet_plants\nfamily_2.1 Anatinae                0.14
# 454                non_sim\nwebbed-feet                0.14
# 1108               diet_plants\nnon_sim                0.14
# 397                 family_2.1 Anatinae                0.14
# 1050            diet_frogs\nlong-billed                0.08
# 401                diet_plants\nnon_sim                0.14
# 1703    diet_small-rodents\nlong-billed                0.08
# 1705            wading-bird\ndiet_frogs                0.08
#
#       consequent support  support  confidence       lift  leverage  \
# 1700                0.08     0.08         1.0  12.500000    0.0736
# 1110                0.14     0.14         1.0   7.142857    0.1204
# 1052                0.08     0.08         1.0  12.500000    0.0736
# 1053                0.08     0.08         1.0  12.500000    0.0736
# 1099                0.14     0.14         1.0   7.142857    0.1204
# 1103                0.14     0.14         1.0   7.142857    0.1204
# 1105                0.14     0.14         1.0   7.142857    0.1204
# 1106                0.14     0.14         1.0   7.142857    0.1204
# 454                 0.14     0.14         1.0   7.142857    0.1204
# 1108                0.14     0.14         1.0   7.142857    0.1204
# 397                 0.14     0.14         1.0   7.142857    0.1204
# 1050                0.08     0.08         1.0  12.500000    0.0736
# 401                 0.14     0.14         1.0   7.142857    0.1204
# 1703                0.08     0.08         1.0  12.500000    0.0736
# 1705                0.08     0.08         1.0  12.500000    0.0736
#
#       conviction  zhangs_metric  combined_product
# 1700         inf            1.0              0.25
# 1110         inf            1.0              0.25
# 1052         inf            1.0              0.25
# 1053         inf            1.0              0.25
# 1099         inf            1.0              0.25
# 1103         inf            1.0              0.25
# 1105         inf            1.0              0.25
# 1106         inf            1.0              0.25
# 454          inf            1.0              0.25
# 1108         inf            1.0              0.25
# 397          inf            1.0              0.25
# 1050         inf            1.0              0.25
# 401          inf            1.0              0.25
# 1703         inf            1.0              0.25
# 1705         inf            1.0              0.25

# %% [markdown]
# ## Iteration-3 Numerical features

# %%
def range_to_mid(r: str) -> float:
    '''
    Return the mid value of a numerical range or a digit
    '''
    if isinstance(r, str) and '-' in r:
        lower_bound, upper_bound = list(map(int,r.split('-')))
        return (lower_bound + upper_bound) / 2
    elif r.isdigit():
        return float(r)
    else:
        raise TypeError("Input should be a numerical range or a single value as a string.")

    

def min_max_scaling(d: np.ndarray) -> np.ndarray:
    min_val = d.min()
    max_val = d.max()
    return (d-min_val) / (max_val - min_val)

# %%
num_range_cols = ['length', 'wspan', 'weight', 'eggs']
other_num = ['AR', 'wload']

add_new_columns(data, encoded_features, num_range_cols, booleanize= False)
add_new_columns(data, encoded_features, other_num, booleanize= False)

encoded_features.T.iloc[70:, :2]
# Out:
#                     0         1
# webbed-feet      True      True
# long-legs       False     False
# wading-bird     False     False
# plunge-dives     True      True
# length          34-38     55-65
# wspan           86-99   123-148
# weight        200-350  800-1300
# eggs              1-3       1-3
# AR               8.13      8.24
# wload            0.31      0.64

# %%
# map numerical ranges to their mid points
encoded_features[num_range_cols] = encoded_features[num_range_cols].map(range_to_mid)
encoded_features.rename(columns={col: f'mid_{col}' for col in num_range_cols}, inplace=True)


# Calculate two new features BMI and WSI
encoded_features['BMI'] = encoded_features['mid_weight'] / (encoded_features['mid_length'] ** 2)
encoded_features['WSI'] = encoded_features['mid_wspan'] / encoded_features['mid_length']






encoded_features.T.iloc[70:, :2]
# Out:
#                      0         1
# webbed-feet       True      True
# long-legs        False     False
# wading-bird      False     False
# plunge-dives      True      True
# mid_length        36.0      60.0
# mid_wspan         92.5     135.5
# mid_weight       275.0    1050.0
# mid_eggs           2.0       2.0
# AR                8.13      8.24
# wload             0.31      0.64
# BMI           0.212191  0.291667
# WSI           2.569444  2.258333

# %%
def encode_top80_numericals_as1HE_column(df: pd.DataFrame, column: str) -> pd.DataFrame:
    """ 
    turns the numerical column into a 1HE column and drops the original column
    """

    if column not in df.columns:
        raise ValueError(f"Column '{column}' does not exist in the DataFrame.")

    # get the columns that are part of the top 80 percentile of that column values 
    limit = df[column].quantile(0.80)

    new_col_name = f'top80_{column}'


    df[new_col_name] = (df[column] >= limit)

    # assigning to df again to emulate in-place modification
    df = df.drop(columns=[column])
    return df

# %%
numerical_compound_columns = ['AR', 'wload', 'WSI', 'BMI', 'mid_eggs']
for column in numerical_compound_columns:
    encoded_features  = encode_top80_numericals_as1HE_column(encoded_features, column=column)

# %%
encoded_features.T.iloc[70:, :2]
# Out:
#                     0       1
# webbed-feet      True    True
# long-legs       False   False
# wading-bird     False   False
# plunge-dives     True    True
# mid_length       36.0    60.0
# mid_wspan        92.5   135.5
# mid_weight      275.0  1050.0
# top80_AR         True    True
# top80_wload     False   False
# top80_WSI        True    True
# top80_BMI       False   False
# top80_mid_eggs  False   False

# %%
mid_columns = [f'mid_{col}' for col in num_range_cols if col != 'eggs']
mid_columns
# Out:
# ['mid_length', 'mid_wspan', 'mid_weight']

# %%
encoded_features.drop(columns=mid_columns, inplace=True)

encoded_features.T.iloc[70:, :15]
# Out:
#                    0      1      2      3      4      5      6      7      8   \
# webbed-feet      True   True   True   True   True  False  False  False  False
# long-legs       False  False  False  False  False   True  False  False   True
# wading-bird     False  False  False  False  False   True   True   True   True
# plunge-dives     True   True   True   True   True  False  False  False  False
# top80_AR         True   True   True   True   True  False  False  False  False
# top80_wload     False  False  False  False  False  False  False  False  False
# top80_WSI        True   True   True  False  False  False  False  False  False
# top80_BMI       False  False  False  False  False  False  False  False  False
# top80_mid_eggs  False  False  False  False  False  False  False  False  False
#
#                    9      10     11     12     13     14
# webbed-feet     False  False  False  False  False  False
# long-legs        True  False  False  False  False  False
# wading-bird      True   True   True   True   True   True
# plunge-dives    False  False  False  False  False  False
# top80_AR        False  False  False  False  False  False
# top80_wload     False  False  False  False  False  False
# top80_WSI       False  False  False  False  False  False
# top80_BMI       False  False  False  False  False  False
# top80_mid_eggs  False  False  False  False  False  False

# %% [markdown]
# ### Iteration-3 Apriori

# %%
# Example: Set maximum width for display columns
pd.set_option('display.max_colwidth', None)  # This sets no limit on column width
pd.set_option('display.max_columns', None)   # Show all columns
output_rules_apriori(df = encoded_features)
# Out:
#                                                                                                                                                                                                               antecedents  \
# 1843                                                                                                       f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nn\no\nn\n_\ns\ni\nm\n'\n}\n)
# 3542                                                                      f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nw\na\nd\ni\nn\ng\n-\nb\ni\nr\nd\n'\n\n\n \n'\nd\ni\ne\nt\n_\ns\nm\na\nl\nl\n-\nr\no\nd\ne\nn\nt\ns\n'\n}\n)
# 3543                                                                                              f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nw\na\nd\ni\nn\ng\n-\nb\ni\nr\nd\n'\n\n\n \n'\nd\ni\ne\nt\n_\nf\nr\no\ng\ns\n'\n}\n)
# 3544                                                                      f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\ns\nm\na\nl\nl\n-\nr\no\nd\ne\nn\nt\ns\n'\n\n\n \n'\nl\no\nn\ng\n-\nb\ni\nl\nl\ne\nd\n'\n}\n)
# 3545                                                                                              f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\nf\nr\no\ng\ns\n'\n\n\n \n'\nl\no\nn\ng\n-\nb\ni\nl\nl\ne\nd\n'\n}\n)
# 1862                                                                                                                 f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 1863                                    f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nt\no\np\n8\n0\n_\nm\ni\nd\n_\ne\ng\ng\ns\n'\n\n\n \n'\nw\ne\nb\nb\ne\nd\n-\nf\ne\ne\nt\n'\n}\n)
# 3616  f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nt\no\np\n8\n0\n_\nm\ni\nd\n_\ne\ng\ng\ns\n'\n\n\n \n'\nn\no\nn\n_\ns\ni\nm\n'\n\n\n \n'\nw\ne\nb\nb\ne\nd\n-\nf\ne\ne\nt\n'\n}\n)
# 3620                                                f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nt\no\np\n8\n0\n_\nm\ni\nd\n_\ne\ng\ng\ns\n'\n\n\n \n'\nn\no\nn\n_\ns\ni\nm\n'\n}\n)
# 3622                                                         f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nn\no\nn\n_\ns\ni\nm\n'\n\n\n \n'\nw\ne\nb\nb\ne\nd\n-\nf\ne\ne\nt\n'\n}\n)
# 3624                                                f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nt\no\np\n8\n0\n_\nm\ni\nd\n_\ne\ng\ng\ns\n'\n\n\n \n'\nn\no\nn\n_\ns\ni\nm\n'\n\n\n \n'\nw\ne\nb\nb\ne\nd\n-\nf\ne\ne\nt\n'\n}\n)
# 3626            f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nt\no\np\n8\n0\n_\nm\ni\nd\n_\ne\ng\ng\ns\n'\n\n\n \n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 3628                     f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nw\ne\nb\nb\ne\nd\n-\nf\ne\ne\nt\n'\n\n\n \n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 3629            f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nt\no\np\n8\n0\n_\nm\ni\nd\n_\ne\ng\ng\ns\n'\n\n\n \n'\nw\ne\nb\nb\ne\nd\n-\nf\ne\ne\nt\n'\n\n\n \n'\nf\na\nm\ni\nl\ny\n_\n2\n.\n1\n \nA\nn\na\nt\ni\nn\na\ne\n'\n}\n)
# 3630                                                                                                       f\nr\no\nz\ne\nn\ns\ne\nt\n(\n{\n'\nd\ni\ne\nt\n_\np\nl\na\nn\nt\ns\n'\n\n\n \n'\nn\no\nn\n_\ns\ni\nm\n'\n}\n)
#
#                                            consequents  antecedent support  \
# 1843                  webbed-feet\nfamily_2.1 Anatinae                0.14
# 3542                      sim\ndiet_frogs\nlong-billed                0.08
# 3543              diet_small-rodents\nsim\nlong-billed                0.08
# 3544                      wading-bird\nsim\ndiet_frogs                0.08
# 3545              wading-bird\ndiet_small-rodents\nsim                0.08
# 1862              diet_plants\ntop80_mid_eggs\nnon_sim                0.14
# 1863                               family_2.1 Anatinae                0.14
# 3616                               family_2.1 Anatinae                0.14
# 3620                  webbed-feet\nfamily_2.1 Anatinae                0.14
# 3622               top80_mid_eggs\nfamily_2.1 Anatinae                0.14
# 3624                  diet_plants\nfamily_2.1 Anatinae                0.14
# 3626                              non_sim\nwebbed-feet                0.14
# 3628                           top80_mid_eggs\nnon_sim                0.14
# 3629                              diet_plants\nnon_sim                0.14
# 3630  top80_mid_eggs\nwebbed-feet\nfamily_2.1 Anatinae                0.14
#
#       consequent support  support  confidence       lift  leverage  \
# 1843                0.14     0.14         1.0   7.142857    0.1204
# 3542                0.08     0.08         1.0  12.500000    0.0736
# 3543                0.08     0.08         1.0  12.500000    0.0736
# 3544                0.08     0.08         1.0  12.500000    0.0736
# 3545                0.08     0.08         1.0  12.500000    0.0736
# 1862                0.14     0.14         1.0   7.142857    0.1204
# 1863                0.14     0.14         1.0   7.142857    0.1204
# 3616                0.14     0.14         1.0   7.142857    0.1204
# 3620                0.14     0.14         1.0   7.142857    0.1204
# 3622                0.14     0.14         1.0   7.142857    0.1204
# 3624                0.14     0.14         1.0   7.142857    0.1204
# 3626                0.14     0.14         1.0   7.142857    0.1204
# 3628                0.14     0.14         1.0   7.142857    0.1204
# 3629                0.14     0.14         1.0   7.142857    0.1204
# 3630                0.14     0.14         1.0   7.142857    0.1204
#
#       conviction  zhangs_metric  combined_product
# 1843         inf            1.0              0.25
# 3542         inf            1.0              0.25
# 3543         inf            1.0              0.25
# 3544         inf            1.0              0.25
# 3545         inf            1.0              0.25
# 1862         inf            1.0              0.25
# 1863         inf            1.0              0.25
# 3616         inf            1.0              0.25
# 3620         inf            1.0              0.25
# 3622         inf            1.0              0.25
# 3624         inf            1.0              0.25
# 3626         inf            1.0              0.25
# 3628         inf            1.0              0.25
# 3629         inf            1.0              0.25
# 3630         inf            1.0              0.25
