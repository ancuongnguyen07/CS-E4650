# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Numerical features engineering
#
# ### Data Summary

# %%
data = pd.read_csv('birds2024ext.csv', delimiter=';')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   species       50 non-null     object
#  1   group         50 non-null     object
#  2   length        50 non-null     object
#  3   wspan         50 non-null     object
#  4   weight        50 non-null     object
#  5   AR            50 non-null     float64
#  6   wload         50 non-null     float64
#  7   back          50 non-null     object
#  8   belly         50 non-null     object
#  9   ftype         50 non-null     object
#  10  sim           50 non-null     object
#  11  billcol       50 non-null     object
#  12  legcol        50 non-null     object
#  13  arrives       50 non-null     object
#  14  leaves        50 non-null     object
#  15  eggs          50 non-null     object
#  16  incub         50 non-null     object
#  17  ccare         50 non-null     object
#  18  biotope       50 non-null     object
#  19  diet          50 non-null     object
#  20  diver         50 non-null     object
#  21  long-billed   50 non-null     object
#  22  webbed-feet   50 non-null     object
#  23  long-legs     50 non-null     object
#  24  wading-bird   50 non-null     object
#  25  plunge-dives  50 non-null     object
# dtypes: float64(2), object(24)
# memory usage: 10.3+ KB

# %%
data.T.iloc[:, :4]
# Out:
#                                        0                          1  \
# species                       naurulokki                harmaalokki
# group                            laridae                    laridae
# length                             34-38                      55-65
# wspan                              86-99                    123-148
# weight                           200-350                   800-1300
# AR                                  8.13                       8.24
# wload                               0.31                       0.64
# back                          light grey                bluish grey
# belly                              white                      white
# ftype                                  B                          B
# sim                                  Yes                        Yes
# billcol                              red                     yellow
# legcol                               red                    reddish
# arrives                      March-April                March-April
# leaves                              July            August-December
# eggs                                 1-3                        1-3
# incub                               both                       both
# ccare                               both                       both
# biotope                   lakes,sea-bays  lakes,sea-coast,marshland
# diet          fish,invertebrates,garbage  fish,garbage,chicks,grain
# diver                                 No                         No
# long-billed                           No                         No
# webbed-feet                          Yes                        Yes
# long-legs                             No                         No
# wading-bird                           No                         No
# plunge-dives                         Yes                        Yes
#
#                                              2                  3
# species                               isolokki          kalatiira
# group                                  laridae          sternidae
# length                                   63-68              36-42
# wspan                                  138-158              70-80
# weight                               1000-1800            100-145
# AR                                        8.24               9.14
# wload                                     0.66               0.24
# back                               bluish grey               grey
# belly                                    white              white
# ftype                                        B                  B
# sim                                        Yes                Yes
# billcol                                 yellow                red
# legcol                                 reddish                red
# arrives                               December                May
# leaves                                   March   August-September
# eggs                                         3                1-3
# incub                                     both               both
# ccare                                     both               both
# biotope                    sea-coast, harbours  lakes,archipelago
# diet          fish,eggs,chicks,garbage,carrion               fish
# diver                                       No                 No
# long-billed                                 No                 No
# webbed-feet                                Yes                Yes
# long-legs                                   No                 No
# wading-bird                                 No                 No
# plunge-dives                               Yes                Yes

# %% [markdown]
# ## Iteration-1 features
#
# start with the habitat, group, diet as the first features.

# %%
def extract_features(df, feature_list):
    df_return = df[feature_list].copy()
    return df_return

# %%
# More descriptive naming
feature_list = ['species', 'group', 'biotope', 'diet']
feature_subset = extract_features(data, feature_list=feature_list)
feature_subset.head(5)
# Out:
#        species      group                      biotope  \
# 0   naurulokki    laridae               lakes,sea-bays
# 1  harmaalokki    laridae    lakes,sea-coast,marshland
# 2     isolokki    laridae          sea-coast, harbours
# 3    kalatiira  sternidae            lakes,archipelago
# 4   lapintiira  sternidae  archipelago,lakes,marshland
#
#                                diet
# 0        fish,invertebrates,garbage
# 1         fish,garbage,chicks,grain
# 2  fish,eggs,chicks,garbage,carrion
# 3                              fish
# 4                              fish

# %%
# Check for NaNs
print("NaNs in 'group':", feature_subset['group'].isna().sum())
print("NaNs in 'biotope':", feature_subset['biotope'].isna().sum())
print("NaNs in 'diet':", feature_subset['diet'].isna().sum())

# Check for empty strings
print("Empty strings in 'group':", (feature_subset['group'] == '').sum())
print("Empty strings in 'biotope':", (feature_subset['biotope'] == '').sum())
print("Empty strings in 'diet':", (feature_subset['diet'] == '').sum())
# Out:
# NaNs in 'group': 0
# NaNs in 'biotope': 0
# NaNs in 'diet': 0
# Empty strings in 'group': 0
# Empty strings in 'biotope': 0
# Empty strings in 'diet': 0

# %%
# Function to clean categorical columns
def clean_column(df, column, delimiter=','):
    """
    Cleans a categorical column by:
    - Stripping whitespace
    - Converting to lowercase
    - Standardizing delimiters
    """
    # Remove leading/trailing whitespace and convert to lowercase
    df.loc[:, column] = df[column].str.strip().str.lower()
    
    # Replace multiple spaces with single space using a raw string
    df.loc[:, column] = df[column].str.replace(r'\s+', ' ', regex=True)
    
    # Ensure consistent delimiter spacing
    df.loc[:, column] = df[column].str.replace(f' {delimiter}', delimiter, regex=False)
    df.loc[:, column] = df[column].str.replace(f'{delimiter} ', delimiter, regex=False)
    
    return df


def count_unique_items(df, columns):
    """
    Counts the number of unique items in each specified column of the DataFrame,
    considering that some cell values contain comma-separated items.

    Parameters:
    - df (pd.DataFrame): The DataFrame containing the data.
    - columns (list): List of column names to analyze.

    Returns:
    - dict: A dictionary with column names as keys and unique counts as values.
    """
    unique_counts = {}
    for column in columns:
        unique_items = set()
        for items in df[column].dropna():
            # Split the string by commas and strip whitespace
            split_items = [item.strip() for item in items.split(',')]
            unique_items.update(split_items)
        unique_counts[column] = len(unique_items)
    return unique_counts

# %%
# Calculate unique counts

cols = feature_subset.columns.tolist()[1:]
# Apply cleaning to each categorical column
for column in cols:
    feature_subset = clean_column(feature_subset, column)

unique_counts = count_unique_items(feature_subset, cols)
sum = 0



# Print unique counts
print("\nNumber of Unique Values in Each Column:")
for column, count in unique_counts.items():
    sum += count
    print(f"Column '{column}': {count} unique value(s)")
print(f"total count: {sum} for columns {cols}")
# Out:
# Number of Unique Values in Each Column:
# Column 'group': 14 unique value(s)
# Column 'biotope': 21 unique value(s)
# Column 'diet': 28 unique value(s)
# total count: 63 for columns ['group', 'biotope', 'diet']

# %% [markdown]
# ### One-Hot Encoding
#
# The Apriori algorithm needs the data to be in a 1 hot encoded format with binary values for each feature. thus the 3 features are now subdivided into binary features
#
#
#
# go through groups, if not in array, add it.
# then loop through that arr, and add that to columns.
# then loop through data and add 1 to that col if group is that
# then delete group column
#
#
# pd.concat() in pandas is used to concatenate two or more DataFrames or Series along a particular axis (either rows or columns). You can specify how you want to join the data (e.g., along rows or columns) and whether to keep all data or just the common parts.

# %%
def one_hot_encode_column(df: pd.DataFrame, column: str, unique: bool) -> pd.DataFrame:
    """ 
    encodes the selected column as a binary valued columns

    Parameters:
    - df (pd.DataFrame): The DataFrame containing the data.
    - column: column to process
    - unique (bool): if the column has unique values

    Returns:
    - pd.DataFrame: DataFrame with the original column dropped and new one-hot encoded columns added.
    """
    if column not in df.columns:
        raise ValueError(f"Column '{column}' does not exist in the DataFrame.")

    if unique:
        group_dummies = pd.get_dummies(df[column], prefix=column)
    else: 
        group_dummies = df[column].str.get_dummies(sep=',').rename(columns=lambda x: f'{column}_{x.strip()}')
    

    encoded_features = pd.concat([df.drop(columns=[column]), group_dummies], axis=1)
    return encoded_features
# Out:
#   Cell In[197], line 12
#     """    if column not in df.columns:
#                                       ^
# SyntaxError: invalid syntax

# %%
pd.set_option('display.max_rows', None)  # This will show all rows


for col in ['biotope', 'diet']:
    encoded_features = one_hot_encode_column(feature_subset, col, unique=False)

encoded_features['group'] = one_hot_encode_column(feature_subset, 'group', unique=True)


print(encoded_features.head(1).T)
print("encoded_features.head(1).T.shape", " : " , encoded_features.head(1).T.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_450097/4100754786.py in ?()
#       3
#       4 for col in ['biotope', 'diet']:
#       5     encoded_features = one_hot_encode_column(feature_subset, col, unique=False)
#       6
# ----> 7 encoded_features['group'] = one_hot_encode_column(feature_subset, 'group', unique=True)
#       8
#       9
#      10 print(encoded_features.head(1).T)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
# -> 4301             self._set_item_frame_value(key, value)
#    4302         elif (
#    4303             is_list_like(value)
#    4304             and not self.columns.is_unique
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4425             loc = self.columns.get_loc(key)
#    4426             cols = self.columns[loc]
#    4427             len_cols = 1 if is_scalar(cols) or isinstance(cols, tuple) else len(cols)
#    4428             if len_cols != len(value.columns):
# -> 4429                 raise ValueError("Columns must be same length as key")
#    4430
#    4431             # align right-hand-side columns if self.columns
#    4432             # is multi-index and self[key] is a sub-frame
#
# ValueError: Columns must be same length as key

# %%
pd.set_option('display.max_rows', None)  # This will show all rows

# One-Hot Encode the 'group' Column
group_dummies = pd.get_dummies(feature_subset['group'], prefix='group')

# One-Hot Encode the 'biotope' Column
biotope_expanded = feature_subset['biotope'].str.get_dummies(sep=',').rename(columns=lambda x: f'biotope_{x.strip()}')

# One-Hot Encode the 'diet' Column
diet_expanded = feature_subset['diet'].str.get_dummies(sep=',').rename(columns=lambda x: f'diet_{x.strip()}')

# Concatenate all dummy DataFrames with the original subset, but drop the original 'group', 'biotope', 'diet' columns
encoded_features = pd.concat([feature_subset.drop(columns=['species', 'group', 'biotope', 'diet']), group_dummies, biotope_expanded, diet_expanded], axis=1)
# Display the Encoded Features
print("len(biotope_expanded.columns)" , " ", len(biotope_expanded.columns))
print(encoded_features.head(1).T)
print("encoded_features.head(1).T.shape", " : " , encoded_features.head(1).T.shape)
# Out:
# len(biotope_expanded.columns)   21
#                                  0
# group_accipitridae           False
# group_anserinae              False
# group_ardeidae               False
# group_charadriidae           False
# group_dabbling ducks         False
# group_diving ducks           False
# group_gaviidae               False
# group_gruifores              False
# group_laridae                 True
# group_phalacrocoracidae      False
# group_podicipedidae          False
# group_rallidae               False
# group_scolopacidae           False
# group_sternidae              False
# biotope_archipelago              0
# biotope_coastal-meadows          0
# biotope_fells                    0
# biotope_fields                   0
# biotope_forest-edges             0
# biotope_forests                  0
# biotope_harbours                 0
# biotope_islets                   0
# biotope_lakes                    1
# biotope_marshland                0
# biotope_meadows                  0
# biotope_nutrient-rich-lakes      0
# biotope_pastures                 0
# biotope_ponds                    0
# biotope_reedbeds                 0
# biotope_sea-bays                 1
# biotope_sea-coast                0
# biotope_shores                   0
# biotope_shrub-tundra             0
# biotope_streams                  0
# biotope_wetlands                 0
# diet_algae                       0
# diet_berries                     0
# diet_birds                       0
# diet_carrion                     0
# diet_chicks                      0
# diet_clams                       0
# diet_eggs                        0
# diet_fish                        1
# diet_frogs                       0
# diet_garbage                     1
# diet_grain                       0
# diet_grass                       0
# diet_hares                       0
# diet_insects                     0
# diet_invertebrates               1
# diet_larvae                      0
# diet_lizards                     0
# diet_molluscs                    0
# diet_plants                      0
# diet_rodents                     0
# diet_seeds                       0
# diet_shellfish                   0
# diet_small-rodents               0
# diet_snails                      0
# diet_snakes                      0
# diet_squirrels                   0
# diet_vertebrae                   0
# diet_worms                       0
# encoded_features.head(1).T.shape  :  (63, 1)

# %%
# Check for binary values
print((encoded_features.iloc[:, 1:] <= 1).all().all())  # Should return True

# Check for missing values
# print(encoded_features.isnull().sum())
# Out:
# True

# %% [markdown]
# ### Since association rules are not monotonic, we could find interesting rules by looking at the family of the birds.

# %%
# Assuming 'encoded_features' is the DataFrame that contains the one-hot encoded columns
species_columns = [col for col in encoded_features.columns if col.startswith('group_')]

# Create a mapping dictionary
taxonomy_mapping = {
    'group_laridae': 'Charadriiformes (Lari)',
    'group_sternidae': 'Charadriiformes (Lari)',
    'group_scolopacidae': 'Charadriiformes (Charadrii)',
    'group_charadriidae': 'Charadriiformes (Charadrii)',
    'group_haematopodidae': 'Charadriiformes (Charadrii)',
    'group_anatinae': 'Anatidae',
    'group_anserinae': 'Anatidae',
    'group_gruidae': 'Gruiformes',
    'group_rallidae': 'Gruiformes',
    'group_phalacrocoracidae': 'Phalacrocoracidae',
    'group_podicipedidae': 'Podicipedidae',
    'group_gaviidae': 'Gaviidae',
    'group_ardeidae': 'Ardeidae',
    'group_accipitridae': 'Accipitriformes'
}


print(species_columns)
print(len(species_columns))
# Out:
# ['group_accipitridae', 'group_anserinae', 'group_ardeidae', 'group_charadriidae', 'group_dabbling ducks', 'group_diving ducks', 'group_gaviidae', 'group_gruifores', 'group_laridae', 'group_phalacrocoracidae', 'group_podicipedidae', 'group_rallidae', 'group_scolopacidae', 'group_sternidae']
# 14

# %%
# Function to map the general group based on the true column
def map_general_group(row):
    for col in species_columns:
        if row[col]:  # Check if the group is True
            return taxonomy_mapping.get(col, None)  # Map to general group
    return None

# Apply the mapping to create the new column 'general_group'
encoded_features['general_family'] = encoded_features.apply(map_general_group, axis=1)

# View the DataFrame with the new column

# %%
encoded_features.T.shape

# View the DataFrame with the new column
encoded_features.T.iloc[encoded_features.shape[1] - 5: encoded_features.shape[1]+ 1, :3]

# View the last few columns, including the new 'general_group' column
# encoded_features.head(2).T.iloc[:, [-3, -1]]
# Out:
#                                      0                       1  \
# diet_snakes                          0                       0
# diet_squirrels                       0                       0
# diet_vertebrae                       0                       0
# diet_worms                           0                       0
# general_family  Charadriiformes (Lari)  Charadriiformes (Lari)
#
#                                      2
# diet_snakes                          0
# diet_squirrels                       0
# diet_vertebrae                       0
# diet_worms                           0
# general_family  Charadriiformes (Lari)

# %%
group_dummies_family = pd.get_dummies(encoded_features['general_family'], prefix='family')

encoded_features = pd.concat([encoded_features.drop(columns=['general_family']),  group_dummies_family], axis=1)

# %%
encoded_features.T.iloc[encoded_features.shape[1] - 12: encoded_features.shape[1]+ 1, :3]
# Out:
#                                         0      1      2
# diet_squirrels                          0      0      0
# diet_vertebrae                          0      0      0
# diet_worms                              0      0      0
# family_Accipitriformes              False  False  False
# family_Anatidae                     False  False  False
# family_Ardeidae                     False  False  False
# family_Charadriiformes (Charadrii)  False  False  False
# family_Charadriiformes (Lari)        True   True   True
# family_Gaviidae                     False  False  False
# family_Gruiformes                   False  False  False
# family_Phalacrocoracidae            False  False  False
# family_Podicipedidae                False  False  False

# %%
# Check data types of encoded_features
print("Data Types of Encoded Features:")
print(encoded_features.dtypes)


# Convert all columns to boolean
encoded_features = encoded_features.astype(bool)
# Verify the conversion
print("\nData Types After Conversion:")
print(encoded_features.dtypes)
# Out:
# Data Types of Encoded Features:
# group_accipitridae                     bool
# group_anserinae                        bool
# group_ardeidae                         bool
# group_charadriidae                     bool
# group_dabbling ducks                   bool
# group_diving ducks                     bool
# group_gaviidae                         bool
# group_gruifores                        bool
# group_laridae                          bool
# group_phalacrocoracidae                bool
# group_podicipedidae                    bool
# group_rallidae                         bool
# group_scolopacidae                     bool
# group_sternidae                        bool
# biotope_archipelago                   int64
# biotope_coastal-meadows               int64
# biotope_fells                         int64
# biotope_fields                        int64
# biotope_forest-edges                  int64
# biotope_forests                       int64
# biotope_harbours                      int64
# biotope_islets                        int64
# biotope_lakes                         int64
# biotope_marshland                     int64
# biotope_meadows                       int64
# biotope_nutrient-rich-lakes           int64
# biotope_pastures                      int64
# biotope_ponds                         int64
# biotope_reedbeds                      int64
# biotope_sea-bays                      int64
# biotope_sea-coast                     int64
# biotope_shores                        int64
# biotope_shrub-tundra                  int64
# biotope_streams                       int64
# biotope_wetlands                      int64
# diet_algae                            int64
# diet_berries                          int64
# diet_birds                            int64
# diet_carrion                          int64
# diet_chicks                           int64
# diet_clams                            int64
# diet_eggs                             int64
# diet_fish                             int64
# diet_frogs                            int64
# diet_garbage                          int64
# diet_grain                            int64
# diet_grass                            int64
# diet_hares                            int64
# diet_insects                          int64
# diet_invertebrates                    int64
# diet_larvae                           int64
# diet_lizards                          int64
# diet_molluscs                         int64
# diet_plants                           int64
# diet_rodents                          int64
# diet_seeds                            int64
# diet_shellfish                        int64
# diet_small-rodents                    int64
# diet_snails                           int64
# diet_snakes                           int64
# diet_squirrels                        int64
# diet_vertebrae                        int64
# diet_worms                            int64
# family_Accipitriformes                 bool
# family_Anatidae                        bool
# family_Ardeidae                        bool
# family_Charadriiformes (Charadrii)     bool
# family_Charadriiformes (Lari)          bool
# family_Gaviidae                        bool
# family_Gruiformes                      bool
# family_Phalacrocoracidae               bool
# family_Podicipedidae                   bool
# dtype: object
#
# Data Types After Conversion:
# group_accipitridae                    bool
# group_anserinae                       bool
# group_ardeidae                        bool
# group_charadriidae                    bool
# group_dabbling ducks                  bool
# group_diving ducks                    bool
# group_gaviidae                        bool
# group_gruifores                       bool
# group_laridae                         bool
# group_phalacrocoracidae               bool
# group_podicipedidae                   bool
# group_rallidae                        bool
# group_scolopacidae                    bool
# group_sternidae                       bool
# biotope_archipelago                   bool
# biotope_coastal-meadows               bool
# biotope_fells                         bool
# biotope_fields                        bool
# biotope_forest-edges                  bool
# biotope_forests                       bool
# biotope_harbours                      bool
# biotope_islets                        bool
# biotope_lakes                         bool
# biotope_marshland                     bool
# biotope_meadows                       bool
# biotope_nutrient-rich-lakes           bool
# biotope_pastures                      bool
# biotope_ponds                         bool
# biotope_reedbeds                      bool
# biotope_sea-bays                      bool
# biotope_sea-coast                     bool
# biotope_shores                        bool
# biotope_shrub-tundra                  bool
# biotope_streams                       bool
# biotope_wetlands                      bool
# diet_algae                            bool
# diet_berries                          bool
# diet_birds                            bool
# diet_carrion                          bool
# diet_chicks                           bool
# diet_clams                            bool
# diet_eggs                             bool
# diet_fish                             bool
# diet_frogs                            bool
# diet_garbage                          bool
# diet_grain                            bool
# diet_grass                            bool
# diet_hares                            bool
# diet_insects                          bool
# diet_invertebrates                    bool
# diet_larvae                           bool
# diet_lizards                          bool
# diet_molluscs                         bool
# diet_plants                           bool
# diet_rodents                          bool
# diet_seeds                            bool
# diet_shellfish                        bool
# diet_small-rodents                    bool
# diet_snails                           bool
# diet_snakes                           bool
# diet_squirrels                        bool
# diet_vertebrae                        bool
# diet_worms                            bool
# family_Accipitriformes                bool
# family_Anatidae                       bool
# family_Ardeidae                       bool
# family_Charadriiformes (Charadrii)    bool
# family_Charadriiformes (Lari)         bool
# family_Gaviidae                       bool
# family_Gruiformes                     bool
# family_Phalacrocoracidae              bool
# family_Podicipedidae                  bool
# dtype: object

# %% [markdown]
# ## Apriori Algorithm

# %% [markdown]
# ### Support
#
# The support of an itemset \( X \) is defined as:
#
# $$
# \text{Support}(X) = \frac{\text{Number of transactions containing } X}{\text{Total number of transactions}}
# $$
#
# ### Confidence
#
# The confidence of an association rule \( X \rightarrow Y \) is defined as:
# $$
# \text{Confidence}(X \rightarrow Y) = \frac{\text{Support}(X \cup Y)}{\text{Support}(X)} = P(Y \mid X)
# $$
#
# ### Lift
#
# The lift of an association rule \( X \rightarrow Y \) is defined as:
# $$
# \text{Lift}(X \rightarrow Y) = \frac{\text{Confidence}(X \rightarrow Y)}{\text{Support}(Y)} = \frac{P(Y \mid X)}{P(Y)}
# $$
#
# Alternatively, it can be expressed as:
# $$
# \text{Lift}(X \rightarrow Y) = \frac{\text{Support}(X \cup Y)}{\text{Support}(X) \times \text{Support}(Y)} = \frac{P(Y \mid X)}{P(Y)}
# $$

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Assuming 'encoded_features' has 'species' as the first column
basket = encoded_features.drop('species', axis=1)
# Define minimum support (e.g., 0.05 for 5%)
frequent_itemsets = apriori(basket, min_support=0.05, use_colnames=True)

# Sort by support
frequent_itemsets = frequent_itemsets.sort_values(by='support', ascending=False)
print(len(frequent_itemsets))
frequent_itemsets.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[178], line 2
#       1 # Assuming 'encoded_features' has 'species' as the first column
# ----> 2 basket = encoded_features.drop('species', axis=1)
#       3 # Define minimum support (e.g., 0.05 for 5%)
#       4 frequent_itemsets = apriori(basket, min_support=0.05, use_colnames=True)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['species'] not found in axis"

# %%
# Define minimum confidence (e.g., 0.7 for 70%)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)

# Sort rules by confidence
rules = rules.sort_values(by='confidence', ascending=False)

rules.head(20)
# Out:
#                                            antecedents  \
# 405             (family_Accipitriformes, diet_insects)
# 1                             (family_Accipitriformes)
# 356                 (diet_frogs, biotope_forest-edges)
# 357         (biotope_forest-edges, group_accipitridae)
# 358                             (biotope_forest-edges)
# 207  (diet_invertebrates, diet_plants, biotope_shores)
# 206  (diet_invertebrates, group_dabbling ducks, bio...
# 359     (family_Accipitriformes, biotope_forest-edges)
# 360         (biotope_forest-edges, group_accipitridae)
# 361                             (biotope_forest-edges)
# 238                    (biotope_lakes, diet_shellfish)
# 362              (diet_small-rodents, biotope_forests)
# 200  (diet_invertebrates, group_dabbling ducks, bio...
# 363              (biotope_forests, group_accipitridae)
# 198                    (biotope_lakes, biotope_shores)
# 364          (family_Accipitriformes, biotope_forests)
# 365              (biotope_forests, group_accipitridae)
# 366                   (diet_small-rodents, diet_birds)
# 212           (group_laridae, diet_garbage, diet_fish)
# 213  (group_laridae, diet_garbage, family_Charadrii...
#
#                                            consequents  antecedent support  \
# 405  (diet_frogs, diet_small-rodents, group_accipit...                0.06
# 1                                 (group_accipitridae)                0.16
# 356                               (group_accipitridae)                0.06
# 357                                       (diet_frogs)                0.06
# 358                   (diet_frogs, group_accipitridae)                0.06
# 207                             (group_dabbling ducks)                0.06
# 206                                      (diet_plants)                0.06
# 359                               (group_accipitridae)                0.06
# 360                           (family_Accipitriformes)                0.06
# 361       (family_Accipitriformes, group_accipitridae)                0.06
# 238        (family_Podicipedidae, group_podicipedidae)                0.06
# 362                               (group_accipitridae)                0.06
# 200                                      (diet_plants)                0.06
# 363                               (diet_small-rodents)                0.06
# 198                (group_dabbling ducks, diet_plants)                0.06
# 364                               (group_accipitridae)                0.06
# 365                           (family_Accipitriformes)                0.06
# 366                               (group_accipitridae)                0.06
# 212                    (family_Charadriiformes (Lari))                0.06
# 213                                        (diet_fish)                0.06
#
#      consequent support  support  confidence       lift  leverage  conviction  \
# 405                0.08     0.06         1.0  12.500000    0.0552         inf
# 1                  0.16     0.16         1.0   6.250000    0.1344         inf
# 356                0.16     0.06         1.0   6.250000    0.0504         inf
# 357                0.18     0.06         1.0   5.555556    0.0492         inf
# 358                0.10     0.06         1.0  10.000000    0.0540         inf
# 207                0.10     0.06         1.0  10.000000    0.0540         inf
# 206                0.26     0.06         1.0   3.846154    0.0444         inf
# 359                0.16     0.06         1.0   6.250000    0.0504         inf
# 360                0.16     0.06         1.0   6.250000    0.0504         inf
# 361                0.16     0.06         1.0   6.250000    0.0504         inf
# 238                0.08     0.06         1.0  12.500000    0.0552         inf
# 362                0.16     0.06         1.0   6.250000    0.0504         inf
# 200                0.26     0.06         1.0   3.846154    0.0444         inf
# 363                0.20     0.06         1.0   5.000000    0.0480         inf
# 198                0.10     0.06         1.0  10.000000    0.0540         inf
# 364                0.16     0.06         1.0   6.250000    0.0504         inf
# 365                0.16     0.06         1.0   6.250000    0.0504         inf
# 366                0.16     0.06         1.0   6.250000    0.0504         inf
# 212                0.10     0.06         1.0  10.000000    0.0540         inf
# 213                0.32     0.06         1.0   3.125000    0.0408         inf
#
#      zhangs_metric
# 405       0.978723
# 1         1.000000
# 356       0.893617
# 357       0.872340
# 358       0.957447
# 207       0.957447
# 206       0.787234
# 359       0.893617
# 360       0.893617
# 361       0.893617
# 238       0.978723
# 362       0.893617
# 200       0.787234
# 363       0.851064
# 198       0.957447
# 364       0.893617
# 365       0.893617
# 366       0.893617
# 212       0.957447
# 213       0.723404

# %%
# Example: Rules with lift greater than 1.2
interesting_rules = rules[rules['lift'] > 10]

interesting_rules = interesting_rules.sort_values(by='lift', ascending=False)

interesting_rules.head(20)
# Out:
#                                            antecedents  \
# 338                                  (family_Ardeidae)
# 333                                  (family_Ardeidae)
# 330               (group_ardeidae, diet_small-rodents)
# 331              (family_Ardeidae, diet_small-rodents)
# 332                                   (group_ardeidae)
# 337                                   (group_ardeidae)
# 129                                     (diet_garbage)
# 342                                    (group_laridae)
# 343                                     (diet_garbage)
# 336                      (diet_frogs, family_Ardeidae)
# 335                       (group_ardeidae, diet_frogs)
# 183  (diet_frogs, family_Ardeidae, diet_small-rodents)
# 381                                   (group_ardeidae)
# 120                                    (group_laridae)
# 119                          (diet_fish, diet_garbage)
# 118                         (group_laridae, diet_fish)
# 126     (group_laridae, family_Charadriiformes (Lari))
# 382                                  (family_Ardeidae)
# 121                                     (diet_garbage)
# 127      (diet_garbage, family_Charadriiformes (Lari))
#
#                                         consequents  antecedent support  \
# 338                    (group_ardeidae, diet_frogs)                0.06
# 333            (group_ardeidae, diet_small-rodents)                0.06
# 330                               (family_Ardeidae)                0.06
# 331                                (group_ardeidae)                0.06
# 332           (family_Ardeidae, diet_small-rodents)                0.06
# 337                   (diet_frogs, family_Ardeidae)                0.06
# 129  (group_laridae, family_Charadriiformes (Lari))                0.06
# 342                                  (diet_garbage)                0.06
# 343                                 (group_laridae)                0.06
# 336                                (group_ardeidae)                0.06
# 335                               (family_Ardeidae)                0.06
# 183                                (group_ardeidae)                0.06
# 381                               (family_Ardeidae)                0.06
# 120                       (diet_fish, diet_garbage)                0.06
# 119                                 (group_laridae)                0.06
# 118                                  (diet_garbage)                0.06
# 126                                  (diet_garbage)                0.06
# 382                                (group_ardeidae)                0.06
# 121                      (group_laridae, diet_fish)                0.06
# 127                                 (group_laridae)                0.06
#
#      consequent support  support  confidence       lift  leverage  conviction  \
# 338                0.06     0.06         1.0  16.666667    0.0564         inf
# 333                0.06     0.06         1.0  16.666667    0.0564         inf
# 330                0.06     0.06         1.0  16.666667    0.0564         inf
# 331                0.06     0.06         1.0  16.666667    0.0564         inf
# 332                0.06     0.06         1.0  16.666667    0.0564         inf
# 337                0.06     0.06         1.0  16.666667    0.0564         inf
# 129                0.06     0.06         1.0  16.666667    0.0564         inf
# 342                0.06     0.06         1.0  16.666667    0.0564         inf
# 343                0.06     0.06         1.0  16.666667    0.0564         inf
# 336                0.06     0.06         1.0  16.666667    0.0564         inf
# 335                0.06     0.06         1.0  16.666667    0.0564         inf
# 183                0.06     0.06         1.0  16.666667    0.0564         inf
# 381                0.06     0.06         1.0  16.666667    0.0564         inf
# 120                0.06     0.06         1.0  16.666667    0.0564         inf
# 119                0.06     0.06         1.0  16.666667    0.0564         inf
# 118                0.06     0.06         1.0  16.666667    0.0564         inf
# 126                0.06     0.06         1.0  16.666667    0.0564         inf
# 382                0.06     0.06         1.0  16.666667    0.0564         inf
# 121                0.06     0.06         1.0  16.666667    0.0564         inf
# 127                0.06     0.06         1.0  16.666667    0.0564         inf
#
#      zhangs_metric
# 338            1.0
# 333            1.0
# 330            1.0
# 331            1.0
# 332            1.0
# 337            1.0
# 129            1.0
# 342            1.0
# 343            1.0
# 336            1.0
# 335            1.0
# 183            1.0
# 381            1.0
# 120            1.0
# 119            1.0
# 118            1.0
# 126            1.0
# 382            1.0
# 121            1.0
# 127            1.0

# %%
data.T.iloc[:, :4]
# Out:
#                                        0                          1  \
# species                       naurulokki                harmaalokki
# group                            laridae                    laridae
# length                             34-38                      55-65
# wspan                              86-99                    123-148
# weight                           200-350                   800-1300
# AR                                  8.13                       8.24
# wload                               0.31                       0.64
# back                          light grey                bluish grey
# belly                              white                      white
# ftype                                  B                          B
# sim                                  Yes                        Yes
# billcol                              red                     yellow
# legcol                               red                    reddish
# arrives                      March-April                March-April
# leaves                              July            August-December
# eggs                                 1-3                        1-3
# incub                               both                       both
# ccare                               both                       both
# biotope                   lakes,sea-bays  lakes,sea-coast,marshland
# diet          fish,invertebrates,garbage  fish,garbage,chicks,grain
# diver                                 No                         No
# long-billed                           No                         No
# webbed-feet                          Yes                        Yes
# long-legs                             No                         No
# wading-bird                           No                         No
# plunge-dives                         Yes                        Yes
#
#                                              2                  3
# species                               isolokki          kalatiira
# group                                  laridae          sternidae
# length                                   63-68              36-42
# wspan                                  138-158              70-80
# weight                               1000-1800            100-145
# AR                                        8.24               9.14
# wload                                     0.66               0.24
# back                               bluish grey               grey
# belly                                    white              white
# ftype                                        B                  B
# sim                                        Yes                Yes
# billcol                                 yellow                red
# legcol                                 reddish                red
# arrives                               December                May
# leaves                                   March   August-September
# eggs                                         3                1-3
# incub                                     both               both
# ccare                                     both               both
# biotope                    sea-coast, harbours  lakes,archipelago
# diet          fish,eggs,chicks,garbage,carrion               fish
# diver                                       No                 No
# long-billed                                 No                 No
# webbed-feet                                Yes                Yes
# long-legs                                   No                 No
# wading-bird                                 No                 No
# plunge-dives                               Yes                Yes

# %%
encoded_features.T.iloc[:, :4]
# Out:
#                                         0      1      2      3
# group_accipitridae                  False  False  False  False
# group_anserinae                     False  False  False  False
# group_ardeidae                      False  False  False  False
# group_charadriidae                  False  False  False  False
# group_dabbling ducks                False  False  False  False
# group_diving ducks                  False  False  False  False
# group_gaviidae                      False  False  False  False
# group_gruifores                     False  False  False  False
# group_laridae                        True   True   True  False
# group_phalacrocoracidae             False  False  False  False
# group_podicipedidae                 False  False  False  False
# group_rallidae                      False  False  False  False
# group_scolopacidae                  False  False  False  False
# group_sternidae                     False  False  False   True
# biotope_archipelago                 False  False  False   True
# biotope_coastal-meadows             False  False  False  False
# biotope_fells                       False  False  False  False
# biotope_fields                      False  False  False  False
# biotope_forest-edges                False  False  False  False
# biotope_forests                     False  False  False  False
# biotope_harbours                    False  False   True  False
# biotope_islets                      False  False  False  False
# biotope_lakes                        True   True  False   True
# biotope_marshland                   False   True  False  False
# biotope_meadows                     False  False  False  False
# biotope_nutrient-rich-lakes         False  False  False  False
# biotope_pastures                    False  False  False  False
# biotope_ponds                       False  False  False  False
# biotope_reedbeds                    False  False  False  False
# biotope_sea-bays                     True  False  False  False
# biotope_sea-coast                   False   True   True  False
# biotope_shores                      False  False  False  False
# biotope_shrub-tundra                False  False  False  False
# biotope_streams                     False  False  False  False
# biotope_wetlands                    False  False  False  False
# diet_algae                          False  False  False  False
# diet_berries                        False  False  False  False
# diet_birds                          False  False  False  False
# diet_carrion                        False  False   True  False
# diet_chicks                         False   True   True  False
# diet_clams                          False  False  False  False
# diet_eggs                           False  False   True  False
# diet_fish                            True   True   True   True
# diet_frogs                          False  False  False  False
# diet_garbage                         True   True   True  False
# diet_grain                          False   True  False  False
# diet_grass                          False  False  False  False
# diet_hares                          False  False  False  False
# diet_insects                        False  False  False  False
# diet_invertebrates                   True  False  False  False
# diet_larvae                         False  False  False  False
# diet_lizards                        False  False  False  False
# diet_molluscs                       False  False  False  False
# diet_plants                         False  False  False  False
# diet_rodents                        False  False  False  False
# diet_seeds                          False  False  False  False
# diet_shellfish                      False  False  False  False
# diet_small-rodents                  False  False  False  False
# diet_snails                         False  False  False  False
# diet_snakes                         False  False  False  False
# diet_squirrels                      False  False  False  False
# diet_vertebrae                      False  False  False  False
# diet_worms                          False  False  False  False
# family_Accipitriformes              False  False  False  False
# family_Anatidae                     False  False  False  False
# family_Ardeidae                     False  False  False  False
# family_Charadriiformes (Charadrii)  False  False  False  False
# family_Charadriiformes (Lari)        True   True   True   True
# family_Gaviidae                     False  False  False  False
# family_Gruiformes                   False  False  False  False
# family_Phalacrocoracidae            False  False  False  False
# family_Podicipedidae                False  False  False  False
