# %% [markdown]
# ## Solution

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('birds2024ext.csv', delimiter=';')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   species       50 non-null     object
#  1   group         50 non-null     object
#  2   length        50 non-null     object
#  3   wspan         50 non-null     object
#  4   weight        50 non-null     object
#  5   AR            50 non-null     float64
#  6   wload         50 non-null     float64
#  7   back          50 non-null     object
#  8   belly         50 non-null     object
#  9   ftype         50 non-null     object
#  10  sim           50 non-null     object
#  11  billcol       50 non-null     object
#  12  legcol        50 non-null     object
#  13  arrives       50 non-null     object
#  14  leaves        50 non-null     object
#  15  eggs          50 non-null     object
#  16  incub         50 non-null     object
#  17  ccare         50 non-null     object
#  18  biotope       50 non-null     object
#  19  diet          50 non-null     object
#  20  diver         50 non-null     object
#  21  long-billed   50 non-null     object
#  22  webbed-feet   50 non-null     object
#  23  long-legs     50 non-null     object
#  24  wading-bird   50 non-null     object
#  25  plunge-dives  50 non-null     object
# dtypes: float64(2), object(24)
# memory usage: 10.3+ KB

# %%
data.head(7)
# Out:
#         species         group length    wspan     weight    AR  wload  \
# 0    naurulokki       laridae  34-38    86-99    200-350  8.13   0.31
# 1   harmaalokki       laridae  55-65  123-148   800-1300  8.24   0.64
# 2      isolokki       laridae  63-68  138-158  1000-1800  8.24   0.66
# 3     kalatiira     sternidae  36-42    70-80    100-145  9.14   0.24
# 4    lapintiira     sternidae  33-37    66-77     90-130  8.97   0.20
# 5      suokukko  scolopacidae  25-26    46-49     90-130  6.73   0.36
# 6  taivaanvuohi  scolopacidae  25-27    39-45     90-110  5.91   0.40
#
#             back  belly ftype  ... incub ccare                      biotope  \
# 0     light grey  white     B  ...  both  both               lakes,sea-bays
# 1    bluish grey  white     B  ...  both  both    lakes,sea-coast,marshland
# 2    bluish grey  white     B  ...  both  both          sea-coast, harbours
# 3           grey  white     B  ...  both  both            lakes,archipelago
# 4           grey  white     B  ...  both  both  archipelago,lakes,marshland
# 5  dappled brown  white     C  ...     F     F           marshland,wetlands
# 6  dappled brown  white     C  ...     F     F    marshland,coastal-meadows
#
#                                diet diver long-billed webbed-feet long-legs  \
# 0        fish,invertebrates,garbage    No          No         Yes        No
# 1         fish,garbage,chicks,grain    No          No         Yes        No
# 2  fish,eggs,chicks,garbage,carrion    No          No         Yes        No
# 3                              fish    No          No         Yes        No
# 4                              fish    No          No         Yes        No
# 5               invertebrates,seeds    No          No          No       Yes
# 6                     invertebrates    No         Yes          No        No
#
#   wading-bird plunge-dives
# 0          No          Yes
# 1          No          Yes
# 2          No          Yes
# 3          No          Yes
# 4          No          Yes
# 5         Yes           No
# 6         Yes           No
#
# [7 rows x 26 columns]

# %%
def range_to_mid(r: str) -> float:
    '''
    Return the mid value of a numerical range
    '''
    if not isinstance(r, str) or '-' not in r:
        raise TypeError
    lower_bound, upper_bound = list(map(int,r.split('-')))
    return (lower_bound + upper_bound) / 2


def min_max_scaling(d: np.ndarray) -> np.ndarray:
    min_val = d.min()
    max_val = d.max()
    return (d-min_val) / (max_val - min_val)

def l2_dist(a, b) -> np.ndarray:
    return np.sqrt(np.sum((a - b)**2))
